# %%
import csv
import pprint as pp

# %%
# prints first 5 lines of a dataset
def first_five(dataset):
    for row in dataset[:5]:
        print(row)

# %%
# reading contents from a CSV file
def read_csv(file_name, header=True):
    with open(file_name, encoding='utf8') as fd:
        all_data = list(csv.reader(fd))
    
    if header:
        return all_data[0], all_data[1:]
    return all_data

# %%
# removing parentheses from a given column in the dataset
def remove_parentheses(index, dataset):
    parentheses = ['(', ')']
    
    for row in dataset:
        value = row[index]
        for char in parentheses:
            value = value.replace(char, '')
        row[index] = value

# %%
# for a given column, if it has some content, update to title case
# else update with given unknown value
def update_unknown_or_title(index, unknown, dataset):
    for row in dataset:
        value = row[index]
        if value:
            row[index] = value.title()
        else:
            row[index] = unknown

# %%
# removing parentheses and converting to int for a given column in the dataset
def clean_and_convert_date(index, dataset):
    parentheses = ['(', ')']
    
    for row in dataset:
        value = row[index]
        if value:
            for char in parentheses:
                value = value.replace(char, '')
            row[index] = int(value)

# %%
def remove_character(date):
    bad_characters = ['(', ')', 'c', 'C', '.', 's', 'S', "'", ' ']
    
    for char in bad_characters:
        date = date.replace(char, '')
    
    return date

# %%
# if a given date column has unwanted character, removes it
# and if it is range of years, calculates average
def process_date(index, dataset):
    for row in dataset:
        date = row[index]
        if date:
            date = remove_character(date)
            if '-' in date:
                date_range = list(map(int, date.split('-')))
                date = round(sum(date_range)/len(date_range))
            else:
                date = int(date)
            
            row[index] = date

# %%
# generates frequency table for give column
def frequency_table(index, dataset):
    table = dict()
    
    for row in dataset:
        item = row[index]
        table[item] = table.get(item, 0) + 1
    
    return table

# %%
header, moma = read_csv('artworks.csv')

# %%
print(len(moma))
# Out:
# 16725

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', '(American)', '(1947)', '(2013)', '(Female)', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', '(Spanish)', '(1916)', '(2007)', '(Male)', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', '(French)', '(1870)', '(1943)', '(Male)', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', '(French)', '(1861)', '(1944)', '(Male)', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', '(French)', '(1857)', '(1927)', '(Male)', '1903', 'Photography']

# %%
remove_parentheses(2, moma) # removing parentheses from 'Nationality' column

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', '(Female)', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', '(Male)', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', '(Male)', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', '(Male)', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', '(1857)', '(1927)', '(Male)', '1903', 'Photography']

# %%
remove_parentheses(5, moma) # removing parentheses from 'Gender' column

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', '(1857)', '(1927)', 'Male', '1903', 'Photography']

# %%
update_unknown_or_title(2, 'Nationality Unknown', moma)

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', '(1857)', '(1927)', 'Male', '1903', 'Photography']

# %%
update_unknown_or_title(5, 'Gender Unknown/Other', moma)

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', '(1857)', '(1927)', 'Male', '1903', 'Photography']

# %%
clean_and_convert_date(3, moma) # removing parentheses and converting to int, 'BeginDate' column

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, '(2013)', 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, '(2007)', 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', 1861, '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', 1857, '(1927)', 'Male', '1903', 'Photography']

# %%
clean_and_convert_date(4, moma) # removing parentheses and converting to int, 'EndDate' column

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, 2013, 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, 2007, 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', 1861, 1944, 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', 1857, 1927, 'Male', '1903', 'Photography']

# %%
process_date(6, moma) # 'Date' column

# %%
first_five(moma)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, 2013, 'Female', 1986, 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, 2007, 'Male', 1978, 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', 1900, 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', 1861, 1944, 'Male', 1934, 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1903, 'Photography']

# %%
# we have got an year in which an artist is born
# and also an year in which the art was created
# now we have to get the age of an artist when the art was created

artists_ages = list()
for row in moma:
    birth_year = row[3]
    art_year = row[6]
    
    if birth_year:
        artists_ages.append(art_year - birth_year)
    else:
        artists_ages.append(0)

# %%
# there are some cases where artists' age is very low or negative
# to summarize, we will categorize ages less that 20 as unknown

final_ages = list()
for age in artists_ages:
    if age > 20:
        final_ages.append(age)
    else:
        final_ages.append('Unknown')

# %%
# for simplification, we will be convering ages to decades
# ex: if age is 24, we will consider an artist is in his '20s'

decades = list()
for age in final_ages:
    if age == 'Unknown':
        decades.append(age)
    else:
        decade = str(age)[:-1]
        decade += '0s'
        decades.append(decade)

# %%
# generating frequency table for decades

decades_frequency = dict()
for item in decades:
    decades_frequency[item] = decades_frequency.get(item, 0) + 1

# %%
pp.pprint(decades_frequency)
# Out:
# {'100s': 3,
#  '110s': 3,
#  '20s': 1856,
#  '30s': 4722,
#  '40s': 4081,
#  '50s': 2434,
#  '60s': 1357,
#  '70s': 559,
#  '80s': 364,
#  '90s': 253,
#  'Unknown': 1093}

# %%
artists_freq = frequency_table(1, moma)

# %%
pp.pprint(artists_freq)
# Out:
# {'A. G. Fronzoni': 6,
#  'A. Karra': 1,
#  'A. M. Cassandre': 9,
#  'A. Paramonov': 1,
#  'A. Radishchev': 1,
#  'A. Strachov': 1,
#  'A.R. Penck (Ralf Winkler)': 18,
#  'Aaron Curry': 1,
#  'Aaron Fink': 1,
#  'Aaron Morse': 2,
#  'Aaron Siskind': 19,
#  'Abbas Kiarostami': 1,
#  'Abby Leigh': 1,
#  'Abel Barroso': 1,
#  'Abelardo Morell': 2,
#  'Abigail Child': 1,
#  'Abraham Cruzvillegas': 1,
#  'Abraham Shterenberg': 1,
#  'Abraham Walkowitz': 19,
#  'Abram Games': 7,
#  'Abram Krol': 3,
#  'Achille Castiglioni': 2,
#  'Achille Perilli': 1,
#  'Ad Reinhardt': 5,
#  'Adam Bartos': 1,
#  'Adam Fuss': 1,
#  'Adam Shankman': 1,
#  'Adja Yunkers': 3,
#  'Adolf Abel': 1,
#  'Adolf De Meyer': 1,
#  'Adolf Dehn': 1,
#  'Adolph Gottlieb': 2,
#  'Adolphe Braun': 1,
#  'Adolpho Wildt': 1,
#  'Adrian Allinson': 1,
#  'Adrian Piper': 14,
#  'Adrian Siegel': 2,
#  'Adrian Wiszniewski': 3,
#  'Adriana Maraz-Bernik': 1,
#  'Adrián Villar Rojas': 1,
#  'Adão Pinheiro': 2,
#  'Aenne Biermann': 2,
#  'Agam (Yaacov Agam)': 1,
#  'Agnes Denes': 3,
#  'Agnes Lyall': 1,
#  'Agnes Martin': 3,
#  'Agustín Fernández': 1,
#  'Agustín Hernández Navarro': 2,
#  'Ai Weiwei': 4,
#  'Aijiro Wakita': 1,
#  'Akesuk Tudlik': 1,
#  'Akira Inada': 1,
#  'Akira Matsumoto': 1,
#  'Akira Miyoshi': 1,
#  'Akram Zaatari': 1,
#  'Aktuální umĕni': 1,
#  'Al Held': 4,
#  'Al Taylor': 3,
#  'Alain Resnais': 1,
#  'Alain de La Bourdonnaye': 1,
#  'Alan Berliner': 1,
#  'Alan Charlton': 1,
#  'Alan Davie': 1,
#  'Alan Green': 3,
#  'Alan J. Pakula': 1,
#  'Alan Saret': 2,
#  'Alan Shields': 1,
#  'Alan Turner': 1,
#  'Alberico Morena': 1,
#  'Albert (Albert Mentzel) Flocon': 4,
#  'Albert Angus Turbayne': 1,
#  'Albert Gleizes': 4,
#  'Albert M. Fine': 4,
#  'Albert Marquet': 9,
#  'Albert Nagele': 1,
#  'Albert Newall': 1,
#  'Albert Oehlen': 2,
#  'Albert Renger-Patzsch': 2,
#  'Albert Rudomine': 1,
#  'Albert Swinden': 1,
#  'Alberto Biasi': 1,
#  'Alberto Burri': 2,
#  'Alberto Carol': 1,
#  'Alberto Dutary': 2,
#  'Alberto Giacometti': 12,
#  'Alberto Greco': 4,
#  'Alberto Magnelli': 1,
#  'Album-miscellaneous': 57,
#  'Aldo Augusto de Souza Lima': 1,
#  'Aldo Rossi': 1,
#  'Alec Soth': 1,
#  'Alejandro Otero': 1,
#  'Aleksandr Archipenko': 5,
#  'Aleksandr Arnshtam': 1,
#  'Aleksandr Deineka': 1,
#  'Aleksandr Rodchenko': 43,
#  'Aleksandr Shevchenko': 1,
#  'Aleksandr Sokurov': 1,
#  'Aleksandra Mir': 26,
#  'Aleksei Baev': 1,
#  "Aleksei Den'shin": 1,
#  'Aleksei Gan': 3,
#  'Aleksei Kravchenko': 1,
#  'Aleksei Kruchenykh': 11,
#  'Aleksei Levin': 1,
#  'Alen MacWeeney': 2,
#  'Alessandra Sanguinetti': 1,
#  'Alessandro Pessoli': 1,
#  'Alex Dodge': 1,
#  'Alex Flett': 1,
#  'Alex Israel': 1,
#  'Alex Katz': 29,
#  'Alex Ku': 1,
#  'Alex Moulton': 1,
#  'Alex Oris': 1,
#  'Alex Prager': 1,
#  'Alex Walter Diggelmann': 1,
#  'Alexa Hunter': 1,
#  'Alexander Alland': 1,
#  'Alexander Bally': 1,
#  'Alexander Bogomazov': 1,
#  'Alexander Brook': 2,
#  'Alexander Calder': 13,
#  'Alexander Dobkin': 1,
#  'Alexander Girard': 1,
#  'Alexander Henderson': 3,
#  'Alexander Liberman': 3,
#  'Alexander Payne': 1,
#  'Alexandra Exter': 4,
#  'Alexandre Arrechea': 1,
#  'Alexei Jawlensky': 1,
#  'Alexey Pajitnov': 1,
#  'Alexis Smith': 1,
#  'Alfred A. Hart': 1,
#  'Alfred Capel Cure': 18,
#  'Alfred Dargis': 1,
#  'Alfred E. Green': 1,
#  'Alfred Jarry': 5,
#  'Alfred Jensen': 4,
#  'Alfred Kubin': 1,
#  'Alfred Leslie': 4,
#  'Alfred Lombard': 1,
#  'Alfred Manessier': 1,
#  'Alfred Reth': 1,
#  'Alfred Stieglitz': 19,
#  'Alfred Wallis': 1,
#  'Alfredo Boulton': 3,
#  'Alfredo Cortina': 5,
#  'Alfredo Guido': 1,
#  'Alfredo Hlito': 1,
#  'Alfredo Jaar': 1,
#  'Alfredo Rostgaard': 2,
#  'Alfredo Valente': 1,
#  'Alfredo Volpi': 1,
#  'Alfredo Zalce': 11,
#  'Alice Attie': 2,
#  'Alice Aycock': 2,
#  'Alice Halicka': 3,
#  'Alice Hutchins': 1,
#  'Alice Neel': 1,
#  'Alice Trumbull Mason': 1,
#  'Alighiero Boetti': 40,
#  'Alina Szapocznikow': 3,
#  'Alison Knowles': 5,
#  'Alistair Macready Bell': 1,
#  "Allan D'Arcangelo": 2,
#  'Allan McCollum': 1,
#  'Allan Sekula': 1,
#  'Allen A. Dutton': 1,
#  'Allen Ginsberg': 1,
#  'Allen Jones': 3,
#  'Allen Ruppersberg': 4,
#  'Allyson Strafella': 1,
#  'Almir Mavignier': 4,
#  'Alphonse Levy': 1,
#  'Alphonse Liébert': 1,
#  'Alton Pickens': 2,
#  'Alvar Aalto': 7,
#  'Alvin Baltrop': 2,
#  'Alvin Langdon Coburn': 5,
#  'Alvin Lustig': 14,
#  'Amar Kanwar': 1,
#  'Amedeo Modigliani': 5,
#  'Amelia Peláez Del Casal': 1,
#  'Amelie von Wulffen': 1,
#  'Amy Cutler': 3,
#  'Amédée Ozenfant': 1,
#  'An-My Lê': 3,
#  'Ana Maria Moncalvo': 1,
#  'Ana Mendieta': 2,
#  'Anatol Stern': 1,
#  "Anatol' Petryts'kyi": 2,
#  'Anatoli Lvovich Kaplan': 23,
#  'Anatoly Timofeevich Zverev': 1,
#  'Andrea Büttner': 2,
#  'Andrea Modica': 1,
#  'Andrea Zittel': 2,
#  'Andreas Feininger': 1,
#  'Andrei Gippius': 1,
#  'Andrei Zvyagintsev': 1,
#  'Andrew Joseph Russell': 1,
#  'Andrew Kay Womrath': 1,
#  'Andrew Lord': 1,
#  'Andrew Noren': 1,
#  'Andrew Repasky McElhinney': 3,
#  'Andrew Wyeth': 1,
#  'Andro Wekua': 4,
#  'Andrzej J. Wroblewski': 1,
#  'Andrzej Steinbach': 2,
#  'András Wahorn': 2,
#  'André Beaudin': 3,
#  'André Cadere': 1,
#  'André Calmettes': 1,
#  'André Chapon': 4,
#  'André Collot': 5,
#  'André Derain': 86,
#  'André Dunoyer de Segonzac': 38,
#  'André Favory': 1,
#  'André Fougeron': 1,
#  'André Kertész': 6,
#  'André Lhote': 1,
#  'André Mare': 1,
#  'André Masson': 49,
#  'André Racz': 4,
#  'André Téchiné': 1,
#  'Andy Warhol': 41,
#  'Angel Bracho': 1,
#  'Angelo Savelli': 2,
#  'Angus Fairhurst': 1,
#  'Anish Kapoor': 7,
#  'Ann Hamilton': 1,
#  'Ann Magnuson': 1,
#  'Anna Bella Geiger': 1,
#  'Anna Gaskell': 2,
#  'Anna Halprin': 4,
#  'Anna Maria Maiolino': 6,
#  'Anne Goldthwaite': 1,
#  'Anne Marie Fishbein': 1,
#  'Anne Noggle': 1,
#  'Anne Ryan': 2,
#  'Anne Truitt': 1,
#  'Anne Turyn': 1,
#  'Anne W. Brigman': 1,
#  'Annemarie Heinrich': 1,
#  'Annette Kelm': 1,
#  'Anni Albers': 25,
#  'Ansel Adams': 45,
#  'Anselm Kiefer': 7,
#  'Anthony Barboza': 1,
#  'Anthony Goicolea': 1,
#  'Anthony Gross': 1,
#  'Anthony Harrison': 1,
#  'Anthony McCall': 1,
#  'Anthony Minghella': 1,
#  'Anthony Tennant': 1,
#  'Antoine Pevsner': 1,
#  'Anton Bruehl': 1,
#  'Anton Heyboer': 4,
#  'Anton Stankowski': 1,
#  'Antoni Clavé': 1,
#  'Antoni Llena': 22,
#  'Antoni Tàpies': 27,
#  'Antonio Berni': 2,
#  'Antonio Fernandez Reboiro': 2,
#  'Antonio Frasconi': 41,
#  'Antonio Martorell': 3,
#  'Antonio Mendoza': 9,
#  'Antonio Papasso': 2,
#  'Antonio Reynoso': 2,
#  'Antonio Saura': 17,
#  'Antonio Segui': 3,
#  'Antonio Zoran Music': 2,
#  'Anupama Kundoo': 1,
#  'Apichatpong Weerasethakul': 1,
#  'Apple Industrial Design Group': 1,
#  'April Gornik': 2,
#  'April Greiman': 1,
#  'Ara Peterson': 1,
#  'Arch Connelly': 1,
#  'Ardegno Soffici': 1,
#  'Aristide Maillol': 77,
#  'Arkadii Shishkin': 1,
#  'Arman': 5,
#  'Armand Séguin': 2,
#  'Armando Andrade Tudela': 1,
#  'Armando Iannucci': 1,
#  'Armin Landeck': 1,
#  'Arnaldo Pomodoro': 3,
#  'Arnaud Desplechin': 1,
#  'Arndt': 1,
#  'Arne Jacobsen': 1,
#  'Arnold Genthe': 2,
#  'Arnold Newman': 5,
#  'Arnold Schmidt': 1,
#  'Arnulf Rainer': 8,
#  'Arsen Anton Ostojic': 1,
#  'Arshile Gorky': 3,
#  'Art Chantry': 3,
#  'Art Spiegelman': 1,
#  'Arthur B. Davies': 8,
#  'Arthur Köpcke': 9,
#  'Arthur N. Christie': 1,
#  'Arthur Osver': 1,
#  'Arthur P. Bedou': 1,
#  'Arthur Rothstein': 1,
#  'Arthur Siegel': 1,
#  'Arthur William Brown': 1,
#  'Asger Jorn': 6,
#  'Associated Press': 1,
#  'Atom Egoyan': 1,
#  'Aubrey Beardsley': 1,
#  'Aubrey Schwartz': 2,
#  'August Gaul': 2,
#  'August Kreyenkamp': 1,
#  'August Sander': 105,
#  'August Walla': 1,
#  'Auguste Belloc': 1,
#  'Auguste Herbin': 1,
#  'Auguste Rodin': 4,
#  'Augustin Càrdenas': 1,
#  'Augustin Tschinkel': 4,
#  'Augusto Giacometti': 3,
#  'Augustus Vincent Tack': 1,
#  'Austin Cooper': 2,
#  'Avery Coffey Danziger': 1,
#  'Avery Singer': 1,
#  'Axel Salto': 1,
#  'Ay-O': 7,
#  'Azazel Jacobs': 1,
#  'B. B. Mccormick': 1,
#  'B. Ferrari': 1,
#  'BIG-Bjarke Ingels Group': 2,
#  'Baldwin S. Lee': 1,
#  'Balthus (Baltusz Klossowski de Rola)': 3,
#  'Bani Abidi': 1,
#  'Banks Violette': 1,
#  'Barbara Bloom': 1,
#  'Barbara Bosworth': 1,
#  'Barbara Brändli': 1,
#  'Barbara Buckner': 1,
#  'Barbara Chase-Riboud': 1,
#  'Barbara Crane': 1,
#  'Barbara Hammer': 1,
#  'Barbara Hepworth': 1,
#  'Barbara Kasten': 1,
#  'Barbara Kruger': 8,
#  'Barbara Morgan': 3,
#  'Barbara Olmsted': 1,
#  'Barnaby Furnas': 1,
#  'Barnett Newman': 7,
#  'Barney Bubbles (Colin Fulcher)': 2,
#  'Barry Caillier': 1,
#  'Barry Flanagan': 2,
#  'Barry Le Va': 6,
#  'Barry Levinson': 1,
#  'Barry Shils': 1,
#  'Bart Van Der Leck': 2,
#  'Barthelemy Toguo': 3,
#  'Bas Jan Ader': 1,
#  'Basil Spence': 1,
#  'Batiste Madalena': 5,
#  'Beatrice Riese': 1,
#  'Beatrice Wood': 1,
#  'Beatriz González': 5,
#  'Beatriz Milhazes': 2,
#  'Ben Drury': 1,
#  'Ben Kinmont': 45,
#  'Ben Nicholson': 2,
#  'Ben Sakoguchi': 2,
#  'Ben Schonzeit': 1,
#  'Ben Shahn': 21,
#  'Ben Vautier': 40,
#  'Ben Wittick': 2,
#  'Ben-Zion': 4,
#  'Benedikt Rohner': 1,
#  'Bengt Böckman': 1,
#  'Bengt Landin': 1,
#  'Bengt af Klintberg': 1,
#  'Benjamin Degen': 1,
#  'Benjamin Heisenberg': 1,
#  'Benjamin Kopman': 1,
#  'Benjamin Patterson': 16,
#  'Benjamín Molina': 1,
#  'Benni Efrat': 3,
#  'Benny Andrews': 5,
#  'Bernar Venet': 2,
#  'Bernard Childs': 1,
#  'Bernard Cohen': 2,
#  'Bernard Frize': 1,
#  'Bernard Rancillac': 1,
#  'Bernard Reder': 2,
#  'Bernard Shea Horne': 1,
#  'Bernard Tschumi': 14,
#  'Bernardo Bertolucci': 1,
#  'Bernardo Ortiz Campo': 2,
#  'Berndt Kerkin': 1,
#  'Bernhard Heiliger': 4,
#  'Bernhard Jaeger': 1,
#  'Bernhard Luginbühl': 6,
#  'Bernhard Martin': 1,
#  'Bert Gerresheim': 1,
#  'Bertien van Manen': 3,
#  'Beth Van Hoesen': 8,
#  'Bettina Sellmann': 1,
#  'Betty Clark Little': 1,
#  'Betty Hahn': 1,
#  'Bezalel Schatz': 5,
#  'Bill Arnold': 5,
#  'Bill Brandt': 24,
#  'Bill Burke': 2,
#  'Bill Jensen': 7,
#  'Bill Owens': 2,
#  'Bill Rauhauser': 1,
#  'Bill Viola': 6,
#  'Bill Woodrow': 1,
#  'Billy Al Bengston': 2,
#  'Billy Woodberry': 1,
#  'Birgit Jürgenssen': 1,
#  'Birgit Megerle': 2,
#  'Birgit Skiöld': 2,
#  'Birney Imes III': 1,
#  'Bishin Jumonji': 1,
#  'Blake Rayne': 1,
#  'Blinky Palermo': 4,
#  'Blondie': 1,
#  'Bob Byington': 1,
#  'Bob Cato': 1,
#  'Bob Sheff': 1,
#  'Bob Thall': 1,
#  'Bona': 1,
#  'Boni': 1,
#  'Bonnie Maclean': 1,
#  'Boris Bućan': 5,
#  'Boris Ender': 1,
#  'Boris Mikhailov': 3,
#  'Boris Zemenkov': 1,
#  'Bouchra Khalili': 1,
#  'Brad Kayal': 1,
#  'Bradford Washburn': 3,
#  'Bram van Velde': 4,
#  'Branda Miller': 1,
#  'Brassaï (Gyula Halász)': 18,
#  'Brendan Fowler': 2,
#  'Brett Weston': 17,
#  'Brian Buczak': 1,
#  'Brian DeGraw': 3,
#  'Brian Eno': 1,
#  'Brian J. Watson': 1,
#  'Brian Rose': 2,
#  'Brice Marden': 11,
#  'Bridget Riley': 2,
#  'Brion Gysin': 1,
#  'Bronislaw Zelek': 1,
#  'Brown Brothers': 2,
#  'Bruce Bennet': 1,
#  'Bruce Conner': 16,
#  'Bruce Davidson': 4,
#  'Bruce Fier': 1,
#  'Bruce Gilden': 1,
#  'Bruce Horowitz': 3,
#  'Bruce La Bruce': 2,
#  'Bruce McLean': 11,
#  'Bruce Nauman': 14,
#  'Bruce Witsiepe': 1,
#  'Bruno Munari': 4,
#  'Bruno Zehnder': 1,
#  'Bryan Hunt': 4,
#  'Burgoyne Diller': 1,
#  'Burk Uzzle': 1,
#  'Burt Gillett': 1,
#  'Burton Rice': 1,
#  'Buster Keaton': 1,
#  'Běla Kolářová': 2,
#  'C. Whitney Bender': 1,
#  'Cady Noland': 5,
#  'Cai Guo-Qiang': 2,
#  'Caio Fonseca': 1,
#  'Caldecot Chubb': 1,
#  'Camera Arts Studios': 1,
#  'Cameron Platter': 1,
#  'Camille Bombois': 1,
#  'Camille Bryen': 2,
#  'Camille Henrot': 1,
#  'Campbell Scott': 1,
#  'Candido Portinari': 3,
#  'Candy Kugel': 2,
#  'Cao Fei': 1,
#  'Captain Beefheart (Don Van Vliet)': 1,
#  'Captain William de Wiveleslie Abney': 6,
#  'Cara DeVito': 1,
#  'Carel Visser': 3,
#  'Carey Maxon': 1,
#  'Carl (Carlo) Mense': 1,
#  'Carl Andre': 4,
#  'Carl Apfelschnitt': 1,
#  'Carl Auböck': 2,
#  'Carl Bernhard Graf': 1,
#  'Carl Otto Czeschka': 1,
#  'Carl Pickhardt': 2,
#  'Carl Van Vechten': 1,
#  'Carl-Harry Stålhane': 1,
#  'Carl-Henning Pedersen': 1,
#  'Carles Asensio Monrabà': 1,
#  'Carleton E. Watkins': 1,
#  'Carlfriedrich Claus': 2,
#  'Carlo Alfano': 1,
#  'Carlo Bartoli': 1,
#  'Carlo Brogi': 1,
#  'Carlo Carrà': 1,
#  'Carlo Guarienti': 2,
#  'Carlo Mollino': 1,
#  'Carlo Scarpa': 1,
#  'Carlos Cruz-Diez': 1,
#  'Carlos Garaicoa': 1,
#  'Carlos Herrera': 2,
#  'Carlos Maria Miguel Squirru': 1,
#  'Carlos Mérida': 5,
#  'Carlos Schwabe': 1,
#  'Carlos Silva': 4,
#  'Carmela Gross': 1,
#  'Carmen Herrera': 3,
#  'Carol Block Taback': 2,
#  'Carol Bove': 2,
#  'Carol Rama': 1,
#  'Carol Summers': 2,
#  'Carolee Schneemann': 3,
#  'Carpenter': 1,
#  'Carrie Mae Weems': 3,
#  'Carroll Cloar': 1,
#  'Carroll Dunham': 20,
#  'Carry (Carl Maria) Hauser': 1,
#  'Carybé (Hector Bernabó)': 7,
#  'Catherine Murphy': 1,
#  'Catherine Wagner': 1,
#  'Cathy Wilkes': 1,
#  'Cause': 1,
#  'Cazals': 1,
#  'Cecil Beaton': 1,
#  'Cecil Stephenson': 1,
#  'Cecily Brown': 2,
#  'Cedric Buchet': 1,
#  'Cedric Price': 6,
#  'Cedric Wright': 4,
#  'Celestino Piatti': 2,
#  'Cesar Pelli': 1,
#  'Cesare Peverelli': 4,
#  'Chad Ferber': 2,
#  'Chad Freidrichs': 1,
#  'Chaim Gross': 1,
#  'Chaim Koppelman': 2,
#  'Channa Horwitz': 1,
#  'Chargesheimer (Karl-Heinz Hargesheimer)': 2,
#  'Charles A. Nichols': 5,
#  'Charles Atlas': 1,
#  'Charles Boily': 1,
#  'Charles Burchfield': 4,
#  'Charles Burnett': 1,
#  'Charles Despiau': 15,
#  'Charles Eames': 2,
#  'Charles Gaines': 3,
#  'Charles H. Breed': 2,
#  'Charles H. Currier': 1,
#  'Charles Harbutt': 2,
#  'Charles Henri Ford': 3,
#  'Charles Herbert Woodbury': 1,
#  'Charles Hoff': 1,
#  'Charles I. Berg': 1,
#  'Charles Lassiter': 1,
#  'Charles Maurin': 1,
#  'Charles Norman Sladen': 3,
#  'Charles Nègre': 2,
#  'Charles Pratt': 2,
#  'Charles Quest': 1,
#  'Charles Rennie Mackintosh': 1,
#  'Charles Reutlinger': 1,
#  'Charles Robert Ashbee': 1,
#  'Charles Sheeler': 2,
#  'Charles Smith': 1,
#  'Charles Thurston Thompson': 2,
#  'Charles White': 2,
#  'Charles William Moss': 1,
#  'Charles de Meaux': 1,
#  'Charline von Heyl': 5,
#  'Charlotte Posenenske': 1,
#  'Chas Laborde (Charles Laborde)': 1,
#  'Chauncey Hare': 1,
#  'Cheyney Thompson': 4,
#  'Chicago School of Design': 1,
#  'Chimei Hamada': 2,
#  'Chip Lord': 3,
#  'Chris Burden': 13,
#  'Chris Finley': 3,
#  'Chris Hammerlein': 1,
#  'Chris Hendrik Beekman': 1,
#  'Chris Johanson': 2,
#  'Chris Killip': 3,
#  'Chris Marker': 1,
#  'Chris Miner': 1,
#  'Chris Ofili': 7,
#  'Christa Ehrlich': 1,
#  'Christer Strömholm': 1,
#  'Christian Boltanski': 49,
#  'Christian Dotremont': 1,
#  'Christian Flamm': 1,
#  'Christian Fossier': 2,
#  'Christian Holstad': 6,
#  'Christian Leborg': 1,
#  'Christian Marclay': 7,
#  'Christian Rohlfs': 8,
#  'Christian Schwarzwald': 1,
#  'Christian de Portzamparc': 3,
#  'Christiane Baumgartner': 1,
#  'Christina Galvez': 1,
#  'Christine Hiebert': 1,
#  'Christine Osinski': 1,
#  'Christo': 4,
#  'Christoph Ruckhäberle': 1,
#  'Christopher Bucklow': 1,
#  'Christopher Dresser': 2,
#  'Christopher Knowles': 1,
#  'Christopher Le Brun': 1,
#  'Christopher Martin Hofstetter': 1,
#  'Christopher P. James': 1,
#  'Christopher Richard Wynne Nevinson': 3,
#  'Christopher Williams': 8,
#  'Christopher Wilmarth': 8,
#  'Christopher Wool': 19,
#  'Chryssa': 8,
#  'Chuck Close': 9,
#  'Chuck Jones': 6,
#  'Chuyên Bùi Thac': 1,
#  'Cindy Bernard': 1,
#  'Cindy Sherman': 18,
#  'Cindy van den Bremen': 1,
#  'Claes Oldenburg': 12,
#  'Clare Strand': 1,
#  'Clarence H. White': 8,
#  'Clarence John Laughlin': 4,
#  'Clarence Kennedy': 2,
#  'Claude Chabrol': 1,
#  'Claude Flight': 1,
#  'Claude Parent': 1,
#  'Claudette Schreuders': 1,
#  'Claudia Andujar': 2,
#  'Claudia Comte': 1,
#  'Claudio Cesar': 1,
#  'Claudio Perna': 1,
#  'Clement Cowles': 1,
#  'Cleve Gray': 1,
#  'Clifford and Rosemary Ellis': 1,
#  'Clinton Adams': 1,
#  'Clinton Hill': 2,
#  'Clorindo Testa': 1,
#  'Clyde Geronimi': 2,
#  'Colin Lanceley': 3,
#  'Colin Self': 1,
#  'Colleen Frances Kenyon': 2,
#  'Connie Rasinski': 1,
#  'Conrad Felixmüller': 1,
#  'Conrad Marca-Relli': 1,
#  'Constant (Constant Anton Nieuwenhuys)': 2,
#  'Constantin Brancusi': 5,
#  'Corita Kent (Sister Mary Corita)': 3,
#  'Corneille (Guillaume van Beverloo)': 1,
#  'Cornell Capa': 1,
#  'Corrado Cagli': 1,
#  'Cory Arcangel': 1,
#  'Cosima von Bonin': 1,
#  'Costa Gavras': 1,
#  'Craig Kauffman': 2,
#  'Crispin Jones': 1,
#  'Cristina Iglesias': 2,
#  'Cristobal Arteche': 1,
#  'Cristos Gianakos': 1,
#  'Cristóbal Lehyt': 3,
#  'Curtis Van Buren': 1,
#  'Cy Twombly': 5,
#  'Cyan': 1,
#  'Cyprien Gaillard': 2,
#  'Cyril Edward Power': 1,
#  'Cédric Klapisch': 1,
#  'César (César Baldaccini)': 2,
#  'César Paternosto': 1,
#  'D-L Alvarez': 1,
#  'DIS': 1,
#  'Dagron & Cie.': 1,
#  'Daido Moriyama': 8,
#  'Dale Rogers': 1,
#  'Damien Deroubaix': 2,
#  'Damien Hirst': 9,
#  'Damián Ortega': 1,
#  'Dan Budnik': 1,
#  'Dan Christensen': 1,
#  'Dan Flavin': 5,
#  'Dan Graham': 4,
#  'Dan McCarthy': 1,
#  'Dan Walsh': 3,
#  'Dan Weiner': 6,
#  'Dana Atchley': 1,
#  'Danh Vo': 1,
#  'Daniel Buren': 6,
#  'Daniel González': 2,
#  'Daniel Grataloup': 16,
#  'Daniel Joseph Martinez': 3,
#  'Daniel Libeskind': 3,
#  'Daniel Reeves': 1,
#  'Daniel Richter': 1,
#  'Daniel Schmid': 1,
#  'Daniel Spoerri': 6,
#  'Danielle Jaeggi': 1,
#  'Danilo Barbosa': 1,
#  'Dannielle Tegeder': 1,
#  'Danny Lyon': 5,
#  'Daria Esteva': 1,
#  'Darius Kinsey': 1,
#  'Darrel Ellis': 1,
#  'Dasha Shishkin': 1,
#  'Dave Heath': 2,
#  'Dave Muller': 3,
#  'David Alfaro Siqueiros': 7,
#  'David Askevold': 1,
#  'David Bates': 1,
#  'David Bomberg': 2,
#  'David Bradshaw': 1,
#  'David Brown Milne': 2,
#  'David Freed': 1,
#  'David Goldes': 1,
#  'David Gordon': 3,
#  'David Hand': 1,
#  'David Hare': 1,
#  'David Hartt': 1,
#  'David Henry Gerson': 1,
#  'David Hockney': 23,
#  'David Ireland': 1,
#  'David Jeffrey': 1,
#  'David Klein': 1,
#  'David Lamelas': 1,
#  'David Lance Goines': 1,
#  'David Leach': 2,
#  'David Maljković': 1,
#  'David Marshall Graham': 1,
#  'David Moreno': 5,
#  'David Noonan': 1,
#  'David Octavius Hill': 19,
#  'David Peretz': 1,
#  'David Prifti': 1,
#  'David Rabinowitch': 1,
#  'David Robilliard': 1,
#  'David Rose': 1,
#  'David Salle': 3,
#  'David Seltzer': 1,
#  'David Shrigley': 8,
#  'David Shterenberg': 2,
#  'David Smith': 1,
#  'David Spear': 1,
#  'David Staub': 2,
#  'David Sterenberg': 1,
#  'David Storey': 2,
#  'David Tremlett': 1,
#  'David V. Hayes': 1,
#  'David Vestal': 1,
#  'David Wark Griffith': 4,
#  'David Wing': 1,
#  'David Wojnarowicz': 3,
#  'Davor Vrankic': 4,
#  'De Wain Valentine': 1,
#  'Deborah Fleming Caffery': 1,
#  'Deborah Stratman': 1,
#  'Debra Hampton': 1,
#  'Declan Haun': 1,
#  'Delia R. Gonzalez': 2,
#  'Demetrio Urruchúa': 2,
#  'Denis Brihat': 1,
#  'Denis Constanduros': 1,
#  'Denise Green': 2,
#  'Dennis Farber': 1,
#  'Dennis Hearne': 1,
#  'Dennis Kardon': 1,
#  'Dennis Oppenheim': 7,
#  'Dennis Wheeler': 2,
#  'Derek Ryden': 1,
#  'Destroy All Monsters': 4,
#  'Development and Resource Corp.': 1,
#  'Diana Michener': 1,
#  'Diane Arbus': 8,
#  'Diane Lewis': 1,
#  'Diane Victor': 4,
#  'Dick Higgins': 10,
#  'Dick Lundy': 1,
#  'Didier Faustino': 2,
#  'Diederick Van Kleef': 3,
#  'Diego Rivera': 19,
#  'Dieter Meier': 1,
#  'Dieter Rams': 1,
#  'Dieter Roth': 18,
#  'Dietrich Sayler': 1,
#  'Dirk Bell': 2,
#  'Disney Studios': 3,
#  'Diógenes Paredes': 1,
#  'Djamshed Usmonov': 1,
#  'Dmitrii Mitrokhin': 2,
#  'Dmitrii Sobolev': 1,
#  'Do Ho Suh': 1,
#  'Dolly Perutz': 2,
#  'Don Brown': 1,
#  'Don Hunstein': 1,
#  'Don Worth': 2,
#  'Donald Baechler': 4,
#  'Donald Brun': 1,
#  'Donald C. Fritz': 1,
#  'Donald Judd': 8,
#  'Donald M. Schwartz': 1,
#  'Donald Saff': 1,
#  'Donald Sultan': 16,
#  'Donald Urquhart': 1,
#  'Dong Kingman': 1,
#  'Donigan Cumming': 1,
#  'Dora Jung': 1,
#  'Dora M. Batty': 1,
#  'Dora Maar (Henriette Theodora Markovitch)': 1,
#  'Dorine van der Klei': 4,
#  'Doris Ulmann': 13,
#  'Dorit Margreiter': 1,
#  'Dorothea Lange': 83,
#  'Dorothea Rockburne': 5,
#  'Dorothea Tanning': 1,
#  'Dorothy Dehner': 2,
#  'Dorothy Liebes': 1,
#  'Doug Aitken': 1,
#  'Doug Dubois': 1,
#  'Doug Edge': 1,
#  'Douglas Blau': 1,
#  'Douglas Darden': 10,
#  'Douglas Gordon': 4,
#  'Douglas Huebler': 3,
#  'Douglas Prince': 1,
#  'Dove Bradshaw': 1,
#  'Dr. Harold E. Edgerton': 3,
#  'Dr. Howard Wright': 1,
#  'Dr. Lakra (Jerónimo López Ramírez)': 5,
#  'Dryden Goodwin': 1,
#  'Duane Michals': 1,
#  'Duncan Grant': 1,
#  'Démétrius Emmanuel Galanis': 5,
#  'Dóra Maurer': 3,
#  'Dörte Eissfeldt': 1,
#  'E. M. Cordier': 1,
#  'E. McKnight Kauffer': 33,
#  'E. Powis Jones': 2,
#  'E.L.T. (Edouard Léon Théodore) Mesens': 1,
#  'Eadweard J. Muybridge': 38,
#  'Earl Miller': 1,
#  'Earl S. Tupper': 3,
#  'Eberhard Göschel': 2,
#  'Ed Bowes': 1,
#  'Ed Moses': 6,
#  'Ed Rossbach': 1,
#  'Ed van Der Elsken': 1,
#  'Edda Renouf': 2,
#  'Edgar Arceneaux': 1,
#  'Edgard Tytgat': 4,
#  'Edgardo Miguel Gimenez': 1,
#  'Edi Hirose': 1,
#  'Edin Vélez': 1,
#  'Edith Dekyndt': 2,
#  'Edmund Teske': 3,
#  'Edo Murtic': 2,
#  'Edouard-Léon-Louis Edy-Legrand': 5,
#  'Eduard Renggli': 1,
#  'Eduardo Arroyo': 1,
#  'Eduardo Berliner': 2,
#  'Eduardo Chillida': 3,
#  'Eduardo Paolozzi': 34,
#  'Edvard Munch': 7,
#  'Edward Burne-Jones': 13,
#  'Edward Corbett': 1,
#  'Edward Curtis': 3,
#  'Edward Dwurnik': 1,
#  'Edward Enlin': 1,
#  'Edward Fella': 1,
#  'Edward Fitzgerald': 1,
#  'Edward Gordon Craig': 1,
#  'Edward Higgins': 1,
#  'Edward Hoole': 1,
#  'Edward Hopper': 3,
#  'Edward Kienholz': 1,
#  'Edward Krasiński': 2,
#  'Edward Moulthrop': 2,
#  'Edward Paschke': 2,
#  'Edward Ranney': 4,
#  'Edward Ruscha': 34,
#  'Edward Steichen': 51,
#  'Edward W. Quigley': 1,
#  'Edward Weston': 34,
#  'Edwin Calligan': 1,
#  'Edwin Dickinson': 1,
#  'Edwin Middleton': 1,
#  'Edwin Moore': 1,
#  'Edwin S. Porter': 1,
#  'Edwin Schlossberg': 1,
#  'Eero Saarinen': 1,
#  'Egon Schiele': 1,
#  'Eikoh Hosoe': 1,
#  'Eizi Kanbayashi': 1,
#  'Ekaterina Turova': 2,
#  'El Lissitzky': 18,
#  'Elaine Lustig Cohen': 33,
#  'Elaine de Kooning': 2,
#  'Eldzier Cortor': 1,
#  "Ele D'Artagnan (Michele Lombardi-Toscanini)": 1,
#  'Eleanore Mikus': 7,
#  'Elena Vladimirovna Semenova': 3,
#  'Elfriede Stegemeyer': 1,
#  'Elia Suleiman': 1,
#  'Elie Nadelman': 6,
#  'Eliot Porter': 7,
#  'Elise (Elise Seeds Armitage)': 1,
#  'Elizabeth Lennard': 1,
#  'Elizabeth McLennan': 1,
#  'Elizabeth Murray': 16,
#  'Elizabeth Peyton': 4,
#  'Elizaveta Ignatovich': 1,
#  'Ella Steigelman': 1,
#  'Ellen Brooks': 1,
#  'Ellen Gallagher': 13,
#  'Ellen Kurras': 1,
#  'Ellen Phelan': 2,
#  'Ellen Siegel': 1,
#  'Ellen Spiro': 1,
#  'Elliott Erwitt': 12,
#  'Elliott Hundley': 1,
#  'Ellsworth Kelly': 21,
#  'Eloise Howard': 1,
#  'Eloise Vega Smith': 1,
#  'Elsa Schmid': 1,
#  'Elso Schiavo': 1,
#  'Emil Ganso': 9,
#  'Emil Nolde': 12,
#  'Emil Orlik': 1,
#  'Emile Bondonneau': 1,
#  'Emile Branchard': 1,
#  'Emilio Ambasz': 2,
#  'Emilio Bertonati': 1,
#  'Emilio Pettoruti': 1,
#  'Emilio Sanchez': 4,
#  'Emily Belding': 2,
#  'Emily Fuller': 1,
#  'Emily Hubley': 2,
#  'Emily Jacir': 1,
#  'Emily Roysdon': 1,
#  'Emmett Williams': 10,
#  'Enguérrand Gourgue': 1,
#  'Enrico Baj': 9,
#  'Enrico Bordoni': 1,
#  'Enrique Chagoya': 2,
#  'Enrique Zañartu': 3,
#  'Enzo Mari': 7,
#  'Eric Andersen': 4,
#  'Eric Fischl': 4,
#  'Eric Gill': 3,
#  'Eric Owen Moss': 5,
#  'Eric Staller': 1,
#  'Erich Comeriner': 8,
#  'Erich Heckel': 9,
#  'Erich Mendelsohn': 2,
#  'Erich Mrozek': 1,
#  'Erik Gunnar Asplund': 1,
#  'Erik Nitsche': 1,
#  'Erik van Lieshout': 1,
#  'Erin Shirreff': 1,
#  'Ernest  Trova': 2,
#  'Ernest Fiene': 2,
#  'Ernest J. Bellocq': 10,
#  'Ernest Knee': 1,
#  'Ernesto Caivano': 3,
#  'Ernesto Fontecilla': 2,
#  'Ernesto Neto': 1,
#  'Erno Metzner': 1,
#  'Ernst Barlach': 9,
#  'Ernst Caramelle': 1,
#  'Ernst Haas': 3,
#  'Ernst Keller': 2,
#  'Ernst Lichtblau': 1,
#  'Ernst Ludwig Kirchner': 17,
#  'Ernst Schoedsack': 2,
#  'Ernst Van Leyden': 1,
#  'Ernst Wilhelm Nay': 1,
#  'Errol Morris': 3,
#  'Erwin Pfrang': 2,
#  'Eryk Rocha': 1,
#  'Ester Partegàs': 1,
#  'Esti Schur': 1,
#  'Eszter Haraszty': 1,
#  'Ettore Sottsass': 4,
#  'Eugen Batz': 2,
#  'Eugen Funk': 1,
#  'Eugene Berman': 11,
#  'Eugene Buechel': 1,
#  'Eugene Masselink': 1,
#  'Eugenio Carmi': 4,
#  'Eugenio Dittborn': 2,
#  'Eugène Atget': 705,
#  'Eugène Charles Paul Vavasseur': 1,
#  'Eugène Delacroix': 3,
#  'Eugène Grasset': 1,
#  'Eugène Ionesco': 3,
#  'Eugène Nestor de Kermadec': 4,
#  'Euzhan Palcy': 2,
#  'Eva Lipman': 1,
#  'Eva Rothschild': 1,
#  'Eva Watson-Schütze': 2,
#  'Eva Zeisel': 11,
#  'Evan Holloway': 1,
#  'Evan Roth': 1,
#  'Eve Andrée Laramée': 1,
#  'Eve Aschheim': 1,
#  'Everett Spruce': 1,
#  'Evergon': 1,
#  'Evert Lundquist': 1,
#  'Evgen Mei': 1,
#  'Evgenii Belukha': 1,
#  'Ewald Mataré': 3,
#  'Ewan Gibbs': 1,
#  'Experimental Jetset': 5,
#  'Ezio Gribaudo': 1,
#  'Ezio Martinelli': 1,
#  'Ezio Pirali': 1,
#  'Ezra Stoller': 1,
#  'F. Armbruster': 1,
#  'F.W. Murnau': 1,
#  'Fabian Marcaccio': 1,
#  'Facundo de Zuviría': 3,
#  'Faith Hubley': 3,
#  'Faith Ringgold': 5,
#  'Fang Lijun': 1,
#  'Fannie Hillsmith': 1,
#  'Faouzi Bensaïdi': 1,
#  'Farkas Molnár': 1,
#  'Farnese de Andrade-Neto': 1,
#  'Faurest Davis': 1,
#  'Fayga Ostrower': 1,
#  'Fazal Sheikh': 22,
#  'Federico Castellon': 3,
#  'Felice Beato': 4,
#  'Felipe Ehrenberg': 1,
#  'Felipe Orlando': 3,
#  'Felix Beltran': 1,
#  'Felix Droese': 2,
#  'Felix Gonzalez-Torres': 6,
#  'Felix Harlan': 1,
#  'Ferdinand Hodler': 2,
#  'Fergus Bourke': 2,
#  'Fernand Léger': 30,
#  'Fernando Botero': 2,
#  'Fernando Bryce': 1,
#  'Fernando Castillo': 1,
#  'Fernando Leal': 1,
#  'Fernando Martín Menis': 4,
#  'Filippo De Pisis': 3,
#  'Filippo Tommaso Marinetti': 3,
#  'Finn Juhl': 2,
#  'Fiona Banner': 10,
#  'Flemming Bo Hansen': 1,
#  'Florence Henri': 3,
#  'Florine Stettheimer': 7,
#  'Forbes Johnstone Whiteside': 1,
#  'Forrest Bess': 1,
#  'Fortunato Depero': 1,
#  'Fotograms': 1,
#  'Fougasse (Cyril Kenneth Bird)': 1,
#  'Frances Benjamin Johnston': 22,
#  'Frances Butler': 1,
#  'Francesc Torres': 1,
#  'Francesco Binfaré': 1,
#  'Francesco Cangiullo': 1,
#  'Francesco Clemente': 12,
#  'Francis Alÿs': 18,
#  'Francis Bacon': 1,
#  'Francis Bedford': 3,
#  'Francis Bruguière': 2,
#  'Francis Frith': 35,
#  'Francis Picabia': 3,
#  'Francis Thompson': 1,
#  'Francis Wishart': 2,
#  'Francisco Blanco': 1,
#  'Francisco Dosamantes': 3,
#  'Francisco Matto': 1,
#  'Francisco Toledo': 1,
#  'Francisco de Goya': 23,
#  'Franciszek Starowieyski': 4,
#  'Frank Auerbach': 1,
#  'Frank Badur': 1,
#  'Frank Dobson': 1,
#  'Frank Eugene': 2,
#  'Frank Gohlke': 13,
#  'Frank Graham Holmes': 1,
#  'Frank Hinder': 1,
#  'Frank Jay Haynes': 1,
#  'Frank LaPena': 2,
#  'Frank Lloyd Wright': 112,
#  'Frank Lobdell': 3,
#  'Frank Magnotta': 1,
#  'Frank O. Gehry': 3,
#  'Frank Stella': 17,
#  'Franklin Chenault Watkins': 4,
#  'Frans Masereel': 34,
#  'Frans van der Steen': 2,
#  'František Kalivoda': 6,
#  'František Kupka': 37,
#  'Franz Erhard Walther': 23,
#  'Franz Hitzler': 1,
#  'Franz Josef van der Grinten': 2,
#  'Franz Kline': 1,
#  'Franz Marc': 2,
#  'Franz West': 9,
#  'Franz Wilhelm Seiwert': 8,
#  'François Kollar': 1,
#  'François Morellet': 3,
#  'Françoise Gilot': 1,
#  'Fred Martin': 9,
#  'Fred Niblo': 1,
#  'Fred Sandback': 18,
#  'Fred Stein': 1,
#  'Fred Taylor': 1,
#  'Fred Tomaselli': 1,
#  'Fred W. McDarrah': 4,
#  'Fred Williams': 2,
#  'Fred Wilson': 3,
#  'Frederic Karoly': 1,
#  'Frederic Lieberman': 2,
#  'Frederick Cooper Llosa': 3,
#  'Frederick Edward McWilliam': 1,
#  'Frederick H. Evans': 1,
#  'Frederick H. K. Henrion': 3,
#  'Frederick Kiesler': 5,
#  "Frederick O'Hara": 1,
#  'Frederick Sommer': 6,
#  'Frederick Wiseman': 9,
#  'Friedl Holzer-Kjellberg': 1,
#  'Friedrich Karl Gotsch': 1,
#  'Friedrich Kunath': 3,
#  'Friedrich Meckseper': 2,
#  'Friedrich St. Florian': 3,
#  'Friedrich Vordemberge-Gildewart': 2,
#  'Fritz Bühler': 1,
#  'Fritz Glarner': 6,
#  'Fritz Goro': 1,
#  'Fritz Hellmut Ehmcke': 1,
#  'Fritz Henle': 7,
#  'Fritz Koenig': 1,
#  'Fritz Kühn': 1,
#  'Fritz Schleifer': 1,
#  'Fritz Wotruba': 1,
#  'Friz Freleng': 6,
#  'Fré Cohen': 8,
#  'Fukuhara Roso': 1,
#  'Félix Thiollier': 2,
#  'Félix Vallotton': 10,
#  'G. de Latenay': 1,
#  'Gabisile Nkosi': 1,
#  'Gabor Peterdi': 6,
#  'Gabriel Alix': 1,
#  'Gabriel Lévêque': 1,
#  'Gabriel Orozco': 3,
#  'Gabriel Sierra': 1,
#  'Gabriel de Rumine': 1,
#  'Gabriele Mucchi': 1,
#  'Gabriele Picco': 5,
#  'Gaetano Pesce': 3,
#  'Gajin Kosaka': 1,
#  'Gale': 1,
#  'Galo Galecio': 1,
#  'Garo Antreasian': 12,
#  'Garry Winogrand': 47,
#  'Gary Hume': 2,
#  'Gary Kuehn': 1,
#  'Gary Metz': 1,
#  'Gary Simmons': 1,
#  'Gaston Lachaise': 4,
#  'Gastone Novelli': 4,
#  'Gavin Hood': 1,
#  'Gavin R. Russom': 1,
#  'Gay Block': 3,
#  'Gedi Sibony': 1,
#  'Gego (Gertrud Goldschmidt)': 6,
#  'Gene Davis': 1,
#  'Gene Vass': 1,
#  'Gene Walther': 1,
#  'General Idea': 10,
#  'Geneviève Asse': 7,
#  'Geoff Winningham': 3,
#  'Geoffrey Hendricks': 1,
#  'Geoffrey James': 2,
#  'Georg Baselitz': 14,
#  'Georg Greger': 1,
#  'Georg Kolbe': 1,
#  'Georg Schmid': 1,
#  'Georg Trump': 7,
#  'George A. Swanson': 1,
#  'George A. Tice': 2,
#  'George Ault': 1,
#  'George Barnard': 12,
#  'George Bellows': 1,
#  'George Brecht': 19,
#  'George C. Cox': 2,
#  'George Condo': 5,
#  'George Constant': 1,
#  'George Cruikshank': 1,
#  'George Cukor': 1,
#  'George Einbeck': 1,
#  'George Georgiou': 1,
#  'George Griffin': 5,
#  'George Grosz': 4,
#  'George H. Hake': 1,
#  'George H. Seeley': 1,
#  'George Hoyningen-Huene': 1,
#  'George Krause': 5,
#  'George Lessey': 1,
#  'George Lockwood': 4,
#  'George Lois': 6,
#  'George Maciunas': 72,
#  'George Mather Richards': 1,
#  'George Mejat / Movietone News / Twentieth Century Fox': 1,
#  'George Minne': 1,
#  'George Nelson': 1,
#  'George Ohr': 1,
#  'George Ortman': 4,
#  'George Overbury ("Pop") Hart': 26,
#  'George Platt Lynes': 2,
#  'George Reavey': 1,
#  'George Rickey': 1,
#  'George Roy Hill': 1,
#  'George Segal': 6,
#  'George Stevens': 1,
#  'George Tooker': 1,
#  'George Tscherny': 1,
#  'George Woodman': 1,
#  'George Yuasa': 1,
#  'George Zimbel': 1,
#  'Georges Bataille': 1,
#  'Georges Blanc': 1,
#  'Georges Braque': 19,
#  'Georges Méliès': 2,
#  'Georges Papazoff': 1,
#  'Georges Rouault': 68,
#  'Georges de Feure': 1,
#  'Georges de Zayas': 1,
#  'Georges-Pierre Seurat': 1,
#  'Georgi Zelma': 1,
#  "Georgia O'Keeffe": 1,
#  'Georgii Echeistov': 1,
#  'Georgii Fisher': 1,
#  'Georgii Iakulov': 1,
#  'Georgii Stenberg': 1,
#  'Georgii Tsapok': 1,
#  'Georgy Khomzor': 1,
#  'Ger Lataster': 1,
#  'Ger van Elk': 1,
#  'Gerald Gooch': 1,
#  'Gerald Jackson': 10,
#  'Gerald Laing': 4,
#  'Geraldo de Barros': 1,
#  'Gerd Leufert': 5,
#  'Gerd Winner': 1,
#  'Gerhard Marcks': 1,
#  'Gerhard Richter': 13,
#  'Germaine Dulac': 1,
#  'Germaine Krull': 1,
#  'German Bobe': 1,
#  'Gernot Bubenik': 2,
#  'Gerrit Rietveld': 2,
#  'Gertrude Käsebier': 11,
#  'Gertrude LeRoy Brown': 1,
#  'Getulio Alviani': 2,
#  'Giacchino Altobelli': 1,
#  'Giacomo Balla': 1,
#  'Giacomo Manzù': 4,
#  'Giacomo Soffiantino': 1,
#  'Giancarlo Piretti': 1,
#  'Giandomenico Belotti': 1,
#  'Gianni Dessi': 2,
#  'Gianni Penati': 1,
#  'Gianni-Emilio Simonetti': 1,
#  'Gilbert & George': 1,
#  'Gilbert Lesser': 1,
#  'Gilda Mantilla': 2,
#  'Gilles Peress': 12,
#  'Gilván Samico': 1,
#  'Ginny Bishton': 1,
#  'Gino Colombini': 1,
#  'Gino De Dominicis': 1,
#  'Gino Severini': 1,
#  'Gino Soggetti': 1,
#  'Giorgio Morandi': 5,
#  'Giorgio de Chirico': 15,
#  'Giovanni Pintori': 3,
#  'Giselle Baillie': 1,
#  'Giulio Paolini': 1,
#  'Giulio Turcato': 1,
#  'Giuseppe Penone': 14,
#  'Giuseppe Santomaso': 2,
#  'Giuseppe Viviani': 1,
#  'Giuseppe de Goetzen': 1,
#  'Giò Pomodoro': 1,
#  'Gjon Mili': 3,
#  'Glen Baxter': 3,
#  'Glenn A. Davis': 1,
#  'Glenn Goldberg': 1,
#  'Glenn Ligon': 2,
#  'Glenn O. Coleman': 2,
#  'Glenn Sorensen': 3,
#  'Gloria Cortella': 2,
#  'Gloria della Vittoria': 1,
#  'Gordon Coster': 1,
#  'Gordon Holler': 1,
#  'Gordon Matta-Clark': 2,
#  'Gordon Parks': 3,
#  'Gorgona artists group': 1,
#  'Goro Ike': 1,
#  'Gottfried Honegger': 6,
#  'Grace A. Snyder': 1,
#  'Grace Hartigan': 8,
#  'Graciela Carnevale': 1,
#  'Graciela Iturbide': 3,
#  'Graham Nickson': 2,
#  'Graham Sutherland': 2,
#  'Grant Mudford': 2,
#  'Grapus': 1,
#  'Graziella Urbinati': 2,
#  'Green': 1,
#  'Greg Colson': 3,
#  'Greg Goldberg': 1,
#  'Gregory Amenoff': 1,
#  'Gregory Hoblit': 1,
#  'Gregory Masurovsky': 7,
#  'Grenville Davey': 1,
#  'Greta Von Nessen': 1,
#  'Grete Stern': 1,
#  'Grisha Bruskin': 3,
#  'Gugelot Institute': 1,
#  'Guido van der Werve': 1,
#  'Guillermo Bermúdez': 1,
#  'Guillermo Kuitca': 4,
#  'Guillermo Meza': 1,
#  'Gundula Schulze-Eldowy': 1,
#  'Gunta Stölzl': 13,
#  'Gunvor Nelson': 1,
#  'Gustav Klimt': 2,
#  'Gustav Klutsis': 4,
#  'Gustav Metzger': 3,
#  'Gustav Schenk': 1,
#  'Gustave Doré': 22,
#  'Gustave Le Gray': 6,
#  'Gustave Singier': 2,
#  'Guy Ben-Ner': 1,
#  'Guy Bourdin': 1,
#  'Guy Harloff': 1,
#  'Guy Maddin': 1,
#  'Guy Peellaert': 1,
#  'Guy Ritchie': 1,
#  'Guy Tillim': 1,
#  'Guy de Cointet': 2,
#  'Gwen John': 1,
#  'György Kepes': 3,
#  'György Sándor Ligeti': 1,
#  'Gérard Duchène': 1,
#  'Gérard Schneider': 2,
#  'Gérard Titus-Carmel': 4,
#  'Göran Olsson': 1,
#  'Günter Brus': 5,
#  'Günter Günschel': 3,
#  'Günter Haese': 2,
#  'Günther Förg': 5,
#  'Günther Ssymmank': 1,
#  'Günther Uecker': 3,
#  'H. A. Rothholz': 1,
#  'H. C. Westermann': 4,
#  'Haegue Yang': 4,
#  'Hagbard Elis Bergh': 2,
#  'Hajo Rose': 1,
#  'Hakuyo Fuchigami': 1,
#  'Hal Fischer': 6,
#  'Haluk Akakçe': 1,
#  'Hamilton Luske': 1,
#  'Hamish Fulton': 2,
#  'Hank Willis Thomas': 2,
#  'Hann Trier': 2,
#  'Hannah Höch': 1,
#  'Hannah Wilke': 2,
#  'Hanne Darboven': 4,
#  'Hannelore Baron': 2,
#  'Hannes Schwarz': 1,
#  'Hans Bellmer': 8,
#  'Hans Erni': 9,
#  'Hans Haacke': 2,
#  'Hans Hartung': 1,
#  'Hans Heinrich Palitzsch': 1,
#  'Hans Hillmann': 1,
#  'Hans Hofmann': 2,
#  'Hans Jurgen Spohn': 1,
#  'Hans Meid': 1,
#  'Hans Poelzig': 8,
#  'Hans Purrmann': 1,
#  'Hans Richter': 1,
#  'Hans Unger': 1,
#  'Hans Watzek': 1,
#  'Hans Wegner': 2,
#  'Hans-Peter Feldmann': 14,
#  'Harald V. Uccello': 2,
#  'Harold Altman': 6,
#  'Harold Barling Town': 1,
#  'Harold Krisel': 1,
#  'Harold Paris': 1,
#  'Harrell Fletcher': 6,
#  'Harry Allen': 1,
#  'Harry Bertoia': 2,
#  'Harry Bouras': 1,
#  'Harry Callahan': 43,
#  'Harry Gottlieb': 1,
#  'Harry Lambert': 1,
#  'Harry Suchland': 1,
#  'Harun Farocki': 6,
#  'Harvey Quaytman': 3,
#  'Harvey Tulcensky': 1,
#  'Hasegawa Sabro': 1,
#  'Hayley Tompkins': 3,
#  'Hazel Kingsbury': 1,
#  'Hector Guimard': 1,
#  'Hedda Sterne': 5,
#  'Heinrich Campendonk': 1,
#  'Heinrich Kühn': 2,
#  'Heinrich Vogeler': 1,
#  'Heinz Hajek-Halke': 1,
#  'Heinz Mack': 2,
#  'Heinz Schulz-Neudamm': 1,
#  'Heinz Veuhoff': 2,
#  'Helen De Michiel': 1,
#  'Helen Frankenthaler': 11,
#  'Helen Levitt': 12,
#  'Helena (Mie Yuan Wong) Wong': 1,
#  'Helene Fesenmaier': 4,
#  'Helga Nykopp': 1,
#  'Hella Fischer-Thorer': 1,
#  'Hella Jongerius': 1,
#  'Helmar Lerski': 3,
#  'Helmut A. P. Grieshaber': 4,
#  'Hendrik Nicolaas Werkman': 1,
#  'Hendrik Willem van Loon': 1,
#  'Hendrikus Th. Wijdeveld': 1,
#  'Henning Christiansen': 4,
#  'Henny Cahn': 2,
#  'Henri Cartier-Bresson': 42,
#  'Henri Gaudier-Brzeska': 1,
#  'Henri Georges Adam': 4,
#  'Henri Goetz': 1,
#  'Henri Laurens': 32,
#  'Henri Matisse': 129,
#  'Henri Meunier': 1,
#  'Henri Michaux': 2,
#  'Henri Plaut': 1,
#  'Henri Pribik': 1,
#  'Henri Rivière': 1,
#  'Henri de Toulouse-Lautrec': 19,
#  'Henri-Edmond Cross': 1,
#  'Henri-Gabriel Ibels': 4,
#  'Henri-Gustave Jossot': 1,
#  'Henri-Patrice Dillon': 1,
#  'Henry Flynt': 7,
#  'Henry Hamilton Bennett': 3,
#  'Henry Khudyakov': 1,
#  'Henry Moore': 9,
#  'Henry Patrick Raleigh': 1,
#  'Henry Pearson': 11,
#  'Henry Rosling': 1,
#  'Henry Taylor': 1,
#  'Henryk Stazewski': 1,
#  'Henryk Tomaszewski': 2,
#  'Herb Quick': 1,
#  'Herbert B. Nichols': 1,
#  'Herbert Bayer': 20,
#  'Herbert Danska': 2,
#  'Herbert Katzman': 1,
#  'Herbert Matter': 2,
#  'Herbert Paus': 1,
#  'Herbert Tomlinson': 1,
#  'Herbert W. Kapitzki': 2,
#  'Herman Emmet': 1,
#  'Herman Rose': 1,
#  'Hermann Gretsch': 1,
#  'Hermann Nitsch': 2,
#  'Hernan Bas': 2,
#  'Hideo Yoshihara': 1,
#  'Hideoki Hagiwara': 1,
#  'Hilaire Hiler': 3,
#  'Hilaire-Germain-Edgar Degas': 1,
#  'Hille': 1,
#  'Hippolyte Bayard': 5,
#  'Hiroki Tsukuda': 1,
#  'Hiroko Yamazaki': 1,
#  'Hiromi Tsuchida': 1,
#  'Hiroyuki Tazawa': 1,
#  'Hito Steyerl': 1,
#  'Hitoshi Takekiyo': 1,
#  'Holger Nielsen': 1,
#  'Hollis Frampton': 1,
#  'Homer Page': 1,
#  'Hong Lei': 1,
#  'Honoré Daumier': 1,
#  'Honoré Sharrer': 2,
#  'Horace M. Engle': 2,
#  'Horacio Coppola': 3,
#  'Horst Antes': 8,
#  'Horst B. Baerenz': 1,
#  'Horst Eigen': 1,
#  'Horst Hoheisel': 2,
#  'Horst Janssen': 1,
#  'Horst-Egon Kalinowski': 5,
#  'Howard Chandler Christy': 2,
#  'Howard Guttenplan': 2,
#  'Howard Hodgkin': 3,
#  'Howard S. Leight': 1,
#  'Howardena Pindell': 2,
#  'Huang Yong Ping': 1,
#  'Hubertus von Pilgrim': 1,
#  'Hugo Dreyfuss': 1,
#  'Hugo Erfurth': 1,
#  'Hugo Gellert': 17,
#  'Hugo Robus': 1,
#  'Hugo van Werden': 4,
#  'Huguette Franco': 1,
#  'Huma Bhabha': 2,
#  'Hundertwasser (Friedrich Stowasser)': 2,
#  'Hutzler Manufacturing Co.': 1,
#  'Hélio Oiticica': 2,
#  'Hélène Delprat': 2,
#  'Hércules Barsotti': 1,
#  'Hüseyin Bahri Alptekin': 2,
#  'IMEC': 2,
#  "Ia Rudens'kyi": 1,
#  'Iain Sinclair': 1,
#  'Iakov Chernikhov': 1,
#  'Ian (Hugh Guiler) Hugo': 7,
#  'Ian Breakwell': 2,
#  'Ian Hamilton Finlay': 3,
#  'Ibi Trier Mørch': 1,
#  'Ibrahim El-Salahi': 3,
#  'Ibram Lassaw': 1,
#  'Ida Applebroog': 2,
#  "Ida O'Keeffe": 2,
#  'Idelle L. Feinberg': 1,
#  'Igor Moukhin': 1,
#  "Igor' Terent'ev": 1,
#  'Ikko (Ikko Narahara)': 2,
#  'Ikko Tanaka': 4,
#  "Il'ia Zdanevich": 1,
#  'Ilene Segalove': 1,
#  'Ilse Bing': 12,
#  'Ilya Bolotowsky': 1,
#  'Ilya Kabakov': 6,
#  'Imogen Cunningham': 7,
#  'Inagaki Tomoo': 3,
#  'Ingeborg Gabriel': 2,
#  'Ingmar Bergman': 1,
#  'International Film Service Company/Hearst': 1,
#  'Ira Martin': 1,
#  'Irene Poon': 1,
#  'Irene Siegel': 4,
#  'Irit Batsry': 1,
#  'Irma Boom': 4,
#  'Irving Amen': 1,
#  'Irving Harper': 1,
#  'Irving Penn': 16,
#  'Irving Petlin': 1,
#  'Isa Genzken': 3,
#  'Isamu Noguchi': 3,
#  'Isidoro Ocampo': 3,
#  'Issey Miyake': 1,
#  'István Orosz': 1,
#  'Italo Scanga': 1,
#  'Iurii Annenkov': 4,
#  'Ivan Kliun': 1,
#  'Ivan Le Lorraine Albright': 1,
#  'Ivan Leonidov': 1,
#  'Ivan Picelj': 4,
#  'Ivo Pannaggi': 1,
#  'Iwan Baan': 1,
#  'Iwata Nakayama': 1,
#  'J. Briones': 1,
#  'J. Deplanque': 1,
#  'J. Gurney': 1,
#  'J. Jacquelin': 1,
#  'J. T. Snyder': 1,
#  'J. Thomas Zetterstrom': 1,
#  "J.D. 'Okhai Ojeikere": 1,
#  'J.J.J. (Jean-Jacques-Joachim) Rigal': 5,
#  'Jaap Berghuis': 2,
#  'Jacek Gaj': 1,
#  'Jack Coke’s Farmer’s Co-op': 2,
#  'Jack Goldstein': 1,
#  'Jack Hannah': 3,
#  'Jack King': 4,
#  'Jack Kinney': 5,
#  'Jack Lenor Larsen': 2,
#  'Jack Pierson': 3,
#  'Jack Smith': 3,
#  'Jack Tworkov': 1,
#  'Jack Welpott': 1,
#  'Jack Whitten': 2,
#  'Jack Zajac': 3,
#  'Jackson Pollock': 14,
#  'Jacob August Riis': 5,
#  'Jacob Epstein': 1,
#  'Jacob Jensen': 1,
#  'Jacob Landau': 2,
#  'Jacob Lawrence': 3,
#  'Jacolby Satterwhite': 1,
#  'Jacqueline Poncelet': 1,
#  'Jacques Charlier': 4,
#  'Jacques Lipchitz': 4,
#  'Jacques Nathan-Garamond': 1,
#  'Jacques Rivette': 1,
#  'Jacques Tati': 1,
#  'Jacques Villon': 42,
#  'Jacques-Henri Lartigue': 3,
#  'Jake Berthot': 3,
#  'Jakob (Jack) Friedrich Bollschweiler': 2,
#  'Jakob Steinhardt': 1,
#  'Jakub Szczęsny': 1,
#  'James Boynton': 2,
#  'James Brooks': 1,
#  'James Brown': 12,
#  'James Cameron': 1,
#  'James Casebere': 1,
#  'James Dow': 2,
#  'James Ensor': 8,
#  'James Fitton': 1,
#  'James Forsberg': 2,
#  'James Gleeson': 1,
#  'James Henderson Boyd': 1,
#  'James Henry Daugherty': 1,
#  'James Lee Byars': 5,
#  'James McGarrell': 2,
#  'James McNeill Whistler': 1,
#  'James Merendino': 1,
#  'James Montgomery Flagg': 1,
#  'James Nares': 2,
#  'James Prestini': 13,
#  'James Richards': 1,
#  'James Riddle': 3,
#  'James Risser': 1,
#  'James Rosati': 1,
#  'James Rosenquist': 15,
#  'James Sherwood': 1,
#  'James Siena': 6,
#  'James Stirling': 1,
#  'James Tenney': 1,
#  'James Thurber': 1,
#  'James Turrell': 6,
#  'James Welling': 8,
#  'James Wines': 1,
#  'Jamie Isenstein': 1,
#  'Jamie Reid': 1,
#  'Jan De Cock': 3,
#  'Jan Dibbets': 66,
#  'Jan Forsberg': 1,
#  'Jan Groover': 19,
#  'Jan Hashey': 2,
#  'Jan J. Schoonhoven': 2,
#  'Jan Lebenstein': 2,
#  'Jan Lenica': 3,
#  'Jan Lukas': 1,
#  'Jan Marcussen': 1,
#  'Jan Matulka': 1,
#  'Jan Peacock': 1,
#  'Jan Stussy': 2,
#  'Jan Toorop': 1,
#  'Jan Tschichold': 6,
#  'Jane Dickson': 1,
#  'Jane Hammond': 1,
#  'Janez Bernik': 1,
#  'Janice Kerbel': 2,
#  'Janine Antoni': 1,
#  'Jannis Kounellis': 5,
#  'Janusz Kapusta': 1,
#  'Janusz Lesniak': 5,
#  'Jarbes Lopes': 2,
#  'Jared French': 7,
#  'Jaromír Funke': 2,
#  'Jarrod Beck': 1,
#  'Jason Seley': 1,
#  'Jasper Johns': 76,
#  'Jasper Morrison': 1,
#  'Jaume Solá Valleys': 1,
#  'Jay Bolotin': 3,
#  'Jay D. Sorensen': 1,
#  'Jay DeFeo': 1,
#  'Jay Kyu Lee': 1,
#  'Jay Leyda': 1,
#  'Jay Monroe': 1,
#  'Jay Rosenblatt': 1,
#  'Jean (Hans) Arp': 36,
#  'Jean Bazaine': 1,
#  'Jean Charlot': 18,
#  'Jean Cocteau': 2,
#  'Jean Deyrolle': 1,
#  'Jean Dubuffet': 206,
#  'Jean Fautrier': 6,
#  'Jean Hugo': 3,
#  'Jean Ipoustéguy': 3,
#  'Jean Kellogg': 3,
#  "Jean L'Anselme": 1,
#  'Jean Launois': 1,
#  'Jean Locey': 1,
#  'Jean Lurçat': 19,
#  'Jean Miotte': 1,
#  'Jean Nouvel': 1,
#  'Jean Piaubert': 4,
#  'Jean Pierre Pincemin': 1,
#  'Jean Pougny (Ivan Puni)': 1,
#  'Jean Puy': 1,
#  'Jean Tinguely': 5,
#  'Jean Tschumi': 4,
#  'Jean-Baptiste-Camille Corot': 1,
#  'Jean-Charles Blais': 1,
#  'Jean-Jacques Annaud': 1,
#  'Jean-Louis Boussingault': 1,
#  'Jean-Luc Godard': 3,
#  'Jean-Luc Verna': 2,
#  'Jean-Michel Atlan': 1,
#  'Jean-Michel Basquiat': 1,
#  'Jean-Michel Folon': 1,
#  'Jean-Paul Rappeneau': 1,
#  'Jeanne Reynal': 1,
#  'Jed Johnson': 1,
#  'Jeff Berner': 1,
#  'Jeff Koons': 3,
#  'Jeff Tremaine': 1,
#  'Jeffrey Scales': 1,
#  'Jeffrey Silverthorne': 1,
#  'Jeffrey Wolin': 1,
#  'Jem Cohen': 4,
#  'Jene Highstein': 2,
#  'Jennifer Bartlett': 1,
#  'Jennifer Moon': 1,
#  'Jennifer Pastor': 1,
#  'Jennifer T. Ley': 1,
#  'Jenny Holzer': 3,
#  'Jenny Perlin': 2,
#  'Jens S Jensen': 1,
#  'Jeremy Anderson': 1,
#  'Jeremy Deller': 1,
#  'Jerome Kaplan': 1,
#  'Jerome Liebling': 3,
#  'Jerome Neuner': 18,
#  'Jerome Schueger': 1,
#  'Jerome Simon': 1,
#  'Jerry Berndt': 1,
#  'Jerry Kearns': 1,
#  'Jerry L. Thompson': 1,
#  'Jerry Schatzberg': 1,
#  'Jerry Uelsmann': 6,
#  'Jerzy Czerniawski': 3,
#  'Jerzy Srokowski': 1,
#  'Jesús Morales Aguilar': 1,
#  'Jesús Rafael Soto': 1,
#  'Jesús Tenreiro-Degwitz': 1,
#  'Jewett Campbell': 1,
#  'Jim Amaral': 1,
#  'Jim Dine': 57,
#  'Jim Goldberg': 2,
#  'Jim Hodges': 1,
#  'Jim Jarmusch': 2,
#  'Jim Lambie': 1,
#  'Jim Nutt': 2,
#  'Jim Shaw': 6,
#  'Jimmie Durham': 1,
#  'Jimmy Alcock': 1,
#  'Jimmy DeSana': 2,
#  'Jimmy Ernst': 2,
#  'Jindrich Streit': 1,
#  'Jindřich Štyrský': 1,
#  'Jiro Takamatsu': 2,
#  'Jirí Balcar': 3,
#  'Jirí Kolár': 1,
#  'Jitka Hanzlová': 1,
#  'Jiří Hilmar': 2,
#  'Jo Baer': 6,
#  'JoAnn Verburg': 3,
#  'Joachim Koester': 1,
#  'Joachim Schönfeldt': 1,
#  'Joan Banach': 1,
#  'Joan Fontcuberta': 2,
#  'Joan Jonas': 8,
#  'Joan Junyer': 2,
#  'Joan Lyons': 3,
#  'Joan Miró': 78,
#  'Joan Mitchell': 2,
#  'Joan Webster Price': 1,
#  'Joanna Hogg': 1,
#  'Joaquín Torres-García': 2,
#  'Jochen Lempert': 1,
#  'Jock Reynolds': 2,
#  'Jockum Nordström': 2,
#  'Joe Andoe': 1,
#  'Joe Bradley': 1,
#  'Joe Brainard': 2,
#  'Joe Colombo': 3,
#  'Joe Deal': 2,
#  'Joe Downing': 1,
#  'Joe Goode': 5,
#  'Joe Jones': 7,
#  'Joe Maloney': 1,
#  'Joe Scorsone': 1,
#  'Joe Thompson': 1,
#  'Joe Tilson': 3,
#  'Joel Bass': 1,
#  'Joel Fisher': 1,
#  'Joel Katz': 1,
#  'Joel Lamangan': 1,
#  'Joel Meyerowitz': 5,
#  'Joel Robinson': 1,
#  'Joel Sanders': 2,
#  'Joel Shapiro': 6,
#  'Joel Sternfeld': 2,
#  'Joey Kötting': 5,
#  'Johan Van Der Keuken': 1,
#  'Johann Hahn': 1,
#  'Johann Loetz': 1,
#  'Johanna Billing': 1,
#  'Johanna Calle': 1,
#  'Johannes Gachnang': 5,
#  'Johannes Itten': 2,
#  'Johannes Molzahn': 5,
#  'Johannes Potente': 2,
#  'Johannes Regn': 1,
#  'Johannes Wohnseifer': 1,
#  'John (born Helmut Herzfelde) Heartfield': 2,
#  'John Akomfrah': 1,
#  'John Altoon': 7,
#  'John Anderson': 1,
#  'John Armleder': 12,
#  'John Armstrong': 2,
#  'John Ashbery': 1,
#  'John B. Greene': 5,
#  'John Baldessari': 8,
#  'John Bellany': 2,
#  'John Bock': 1,
#  'John Buckland-Wright': 1,
#  'John Button': 1,
#  'John Cage': 5,
#  'John Candelario': 5,
#  'John Chick': 1,
#  'John Clem Clarke': 1,
#  'John Collins': 1,
#  'John Coplans': 6,
#  'John Craxton': 2,
#  'John Currin': 2,
#  'John D. Graham': 5,
#  'John E. Dumont': 2,
#  'John Edward Dowell': 2,
#  'John Fekner': 1,
#  'John Ferren': 1,
#  'John Follis': 1,
#  'John Freeman': 1,
#  'John G. Bullock': 1,
#  'John Grillo': 1,
#  'John Gutmann': 2,
#  'John Harding': 1,
#  'John Hejduk': 3,
#  'John Houck': 1,
#  'John Hunter': 1,
#  'John Huston': 1,
#  'John J. Cu Roi': 1,
#  'John Kane': 1,
#  'John Langdon': 1,
#  'John Levee': 3,
#  'John Lurie': 3,
#  'John Maeda': 1,
#  'John Mansbridge': 1,
#  'John Marin': 1,
#  'John McGreer': 1,
#  'John McKay': 1,
#  'John McLaughlin': 3,
#  'John Milisenda': 1,
#  "John O'Reilly": 1,
#  'John Piper': 6,
#  'John Ross': 1,
#  'John Schott': 5,
#  'John Scofield': 1,
#  'John Shaw': 1,
#  'John Sloan': 20,
#  'John Smith': 1,
#  'John Storrs': 2,
#  'John Szarkowski': 6,
#  'John Taylor Arms': 1,
#  'John Thomson': 40,
#  'John Vachon': 2,
#  'John W. Church': 1,
#  'John Walker': 7,
#  'John Waters': 1,
#  'John Wesley': 1,
#  'John William Carnell': 1,
#  "Jon T. O'Neal": 1,
#  'Jon Widman': 1,
#  'Jonas J. Fendell': 1,
#  'Jonas Wood': 5,
#  'Jonathan Borofsky': 1,
#  'Jonathan Horowitz': 1,
#  'Jonathan Lasker': 1,
#  'Jonathan Monk': 1,
#  'Jonathas de Andrade': 1,
#  'Joon-ho Bong': 1,
#  'Joost Schmidt': 1,
#  'Jordi Secall Roure': 1,
#  'Jorge Castillo': 10,
#  'Jorge Macchi': 1,
#  'Jorge Pardo': 9,
#  'Jorge Ribalta': 2,
#  'Jorge Rigamonti': 2,
#  'Jorinde Voigt': 2,
#  'Jorre van Ast': 2,
#  'Jos van der Meulen': 1,
#  'Jose Antonio Fernández-Muro': 1,
#  'Jose Espert': 1,
#  'Josef Albers': 38,
#  'Josef Bato': 1,
#  'Josef Eberz': 2,
#  'Josef Gielniak': 1,
#  'Josef Hoffmann': 9,
#  'Josef Koudelka': 8,
#  'Josef Müller-Brockmann': 3,
#  'Josef Peeters': 1,
#  'Josef Scharl': 1,
#  'Josef Sudek': 1,
#  'Josep Subirats Samora': 1,
#  'Joseph Beuys': 11,
#  'Joseph Breitenbach': 1,
#  'Joseph Cornell': 1,
#  'Joseph Dankowski': 9,
#  'Joseph Glasco': 1,
#  'Joseph Grigely': 6,
#  'Joseph Hirsch': 1,
#  'Joseph Janvier Woodward': 1,
#  'Joseph Kosuth': 3,
#  'Joseph Maria Olbrich': 1,
#  'Joseph Nechvatal': 1,
#  'Joseph Pennell': 2,
#  'Joseph Stalnaker': 1,
#  'Josh Smith': 2,
#  'Joshua Light Show': 1,
#  'Josiah McElheny': 2,
#  'Josip Vaništa': 3,
#  'José Antonio Attolini Lack': 9,
#  'José Antonio Suárez Londoño': 48,
#  'José Chávez Morado': 4,
#  'José Clemente Orozco': 5,
#  'José Costa Leite': 2,
#  'José De Creeft': 1,
#  'José Gamarra': 1,
#  'José Leonilson': 1,
#  'José Luis Cuevas': 5,
#  'José María Sicilia': 1,
#  'José R. Alicea': 1,
#  'José Sabogal': 1,
#  'José Yalenti': 1,
#  'José-Guadalupe Posada': 10,
#  'Joyce Kozloff': 2,
#  'Joyce Pensato': 1,
#  'Joyce Sills': 5,
#  'Joyce Treiman': 2,
#  'Joyce Wieland': 3,
#  'Jozsef Rippl-Rónai': 1,
#  'João Luis Sol de Carvalho': 1,
#  'Joël Stein': 1,
#  'Juan Baixas': 10,
#  'Juan Downey': 3,
#  'Juan Genovés': 1,
#  'Juan Gris': 6,
#  'Juan Gómez-Quiroz': 1,
#  'Juan Hidalgo': 7,
#  'Juan Luis Martinez': 2,
#  'Juan Soriano': 1,
#  'Juan Uslé': 3,
#  'Judd Apatow': 2,
#  'Judith Godwin': 1,
#  'Judith Joy Ross': 16,
#  'Judith Shea': 1,
#  'Jules Allen': 1,
#  'Jules Olitski': 3,
#  'Jules Pascin': 40,
#  'Julia Jacquette': 2,
#  'Julia Margaret Cameron': 1,
#  'Julia Wachtel': 1,
#  'Julian Hoeber': 1,
#  'Julian Lethbridge': 3,
#  'Julian Opie': 1,
#  'Julian Schnabel': 1,
#  'Julian Stanczak': 2,
#  'Julie Mehretu': 6,
#  'Julie Taymor': 1,
#  'Julio Agostinelli': 1,
#  'Julio González': 5,
#  'Julio Larraz': 1,
#  'Julio Le Parc': 1,
#  'Julio Palazuelos': 1,
#  'Julio Plaza': 1,
#  'Julio de Diego': 1,
#  'Julius K. Friedman': 3,
#  'Juliusz Studnicki': 3,
#  'Julián Hernández': 1,
#  'Julião Sarmento': 3,
#  'Jun Shiraoka': 1,
#  'June Redfern': 3,
#  'June Wayne': 2,
#  'Junichi Arai': 2,
#  'Junius Redwood': 1,
#  'Junya Ishigami': 1,
#  'Jupp Wiertz': 1,
#  'Justin Matherly': 1,
#  'Justino Fernández': 1,
#  'Ján Mančuška': 2,
#  'Jörg Hamburger': 1,
#  'Jörg Immendorff': 2,
#  'Jürgen Brodwolf': 1,
#  'Jürgen Partenheimer': 8,
#  'K. H. Hödicke': 1,
#  'K.R.H. Sonderborg': 1,
#  'Kai Althoff': 1,
#  'Kaj Franck': 7,
#  'Kalup Linzy': 1,
#  'Kanamori Yoshio': 1,
#  'Kara Walker': 13,
#  'Karel Appel': 3,
#  'Karel Maes': 1,
#  'Karl Bauer': 1,
#  'Karl Bohrmann': 8,
#  'Karl Brown': 1,
#  'Karl Elsener': 1,
#  'Karl Fred Dahmen': 1,
#  'Karl Free': 2,
#  'Karl Gerstner': 3,
#  'Karl Grill': 1,
#  'Karl Haendel': 1,
#  'Karl Hofer': 4,
#  'Karl Knaths': 1,
#  'Karl Koepping': 1,
#  'Karl Ludwig Straub': 1,
#  'Karl Schmidt-Rottluff': 4,
#  'Karl Schrag': 3,
#  'Karl Struss': 1,
#  'Karl Walser': 1,
#  'Karl-Peter Röhl': 1,
#  'Karlheinz Stockhausen': 1,
#  'Kasper König': 1,
#  'Katerina Lanfranco': 1,
#  'Katharina Bosse': 1,
#  'Katharina Fritsch': 3,
#  'Katharina Gaenssler': 1,
#  'Katharina Grosse': 1,
#  'Katharina Wulff': 1,
#  'Katherine Schmidt': 1,
#  'Kathy Acker': 1,
#  'Kati Horna': 1,
#  'Katie Flesicher': 1,
#  'Katinka Mann': 1,
#  'Katsuhiro Yamaguchi': 2,
#  'Katsuro Yoshida': 1,
#  'Katy Grannan': 1,
#  'Katy Schimert': 1,
#  'Kawakami Sumio': 1,
#  'Kawanishi Hide': 2,
#  'Kayrock and Wolfy': 4,
#  'Kazimir Malevich': 10,
#  'Kcho (Alexis Leyva Machado)': 1,
#  'Kees van Dongen': 17,
#  'Keita Takahashi': 1,
#  'Keith Coventry': 1,
#  'Keith Haring': 1,
#  'Keith Milow': 3,
#  'Keith Smith': 1,
#  'Keith Tyson': 1,
#  'Keld Helmer-Petersen': 1,
#  'Kelley Walker': 14,
#  'Ken Domon': 3,
#  'Ken Friedman': 10,
#  'Ken Graves': 1,
#  'Ken Heyman': 1,
#  'Ken Jacobs': 2,
#  'Ken Josephson': 4,
#  'Ken Price': 8,
#  'Ken Schles': 1,
#  'Kengo Kuma': 2,
#  'Kenji Tadamoto': 1,
#  'Kenneth Armitage': 1,
#  'Kenneth Brozen': 2,
#  'Kenneth Hayes Miller': 1,
#  'Kenneth Martin': 1,
#  'Kenneth Snelson': 1,
#  'Kenzo Okada': 1,
#  'Ker-Xavier Roussel': 2,
#  'Kerry James Marshall': 4,
#  'Kerry Tribe': 2,
#  'Kerstin Brätsch': 1,
#  'Kerstin Kartscher': 1,
#  'Ketaki Sheth': 2,
#  'Keystone View Company': 1,
#  'Kiki Smith': 21,
#  'Kikuji Kawada': 2,
#  'Kim Keever': 1,
#  'Kinji Akagawa': 3,
#  'Kipton Kumler': 1,
#  'Kirill Rozhdestvenskii': 1,
#  'Kirill Zdanevich': 5,
#  'Kirstine Roepstorff': 1,
#  'Kitaoji Rosanjin': 1,
#  'Kiyoshi Hasegawa': 1,
#  'Klaas Gubbels': 1,
#  'Klara Liden': 1,
#  'Klaudia Kemper': 1,
#  'Klaus A. Schnitzer': 1,
#  'Klaus Groh': 5,
#  'Klaus Rinke': 2,
#  'Klaus Staeck': 1,
#  'Klára Tamás': 1,
#  'Kn Thurlbeck': 2,
#  'Knut Rumohr': 1,
#  'Koichi Sato': 2,
#  'Koji Iwagami': 1,
#  'Kojo Griffin': 1,
#  'Koloman Moser': 2,
#  'Konstantin Grcic': 3,
#  'Konstantin Rotov': 1,
#  'Koshiro Onchi': 4,
#  'Kosti Ruohomaa': 2,
#  'Kosuke Kimura': 1,
#  'Kristen Corinne Masri': 1,
# ...
#  'Rodolfo Bonetto': 1,
#  'Rodolphe Bresdin': 1,
#  'Rody Graumans': 1,
#  'Roe Ethridge': 4,
#  'Roger Ballen': 1,
#  'Roger Bolomey': 1,
#  'Roger Brown': 3,
#  'Roger C. Ferri': 2,
#  'Roger Chancel': 3,
#  'Roger Chastel': 11,
#  'Roger Fenton': 2,
#  'Roger Mayne': 1,
#  'Roger Mertin': 2,
#  'Roger Parry': 2,
#  'Roger Tallon': 1,
#  'Roger Vieillard': 10,
#  'Roger de La Fresnaye': 9,
#  'Roi Partridge': 1,
#  'Roland Penrose': 1,
#  'Roland Sabatier': 1,
#  'Rolf Harder': 3,
#  'Rolf Nesch': 2,
#  'Rolf Sackenheim': 1,
#  'Rolf Tietgens': 1,
#  'Roloff Beny': 6,
#  'Romain Urhausen': 1,
#  'Roman Cieslewicz': 2,
#  'Roman Scheidl': 1,
#  'Roman Signer': 29,
#  'Roman Vishniac': 1,
#  'Romare Bearden': 1,
#  'Romas Viesulas': 6,
#  'Ronald Bladen': 1,
#  'Ronald Markman': 7,
#  'Ronald R. Geibert': 1,
#  'Roni Horn': 1,
#  'Ronnie Landfield': 1,
#  'Ros Barron': 1,
#  'Rosa Loy': 1,
#  'Rosalind Fox Solomon': 14,
#  'Rosemarie Trockel': 17,
#  'Rosemary Mayer': 1,
#  'Ross McElwee': 1,
#  'Rowe': 1,
#  'Roy Arden': 2,
#  'Roy Lichtenstein': 20,
#  'Rudi Tröger': 1,
#  'Rudolf Baschant': 1,
#  'Rudolf Belling': 1,
#  'Rudolf Eickemeyer Jr.': 1,
#  'Rudolf Grossmann': 3,
#  'Rudolf Kügler': 2,
#  'Rudolf Schoofs': 4,
#  'Rudolf Schwarzkogler': 1,
#  'Rudolf Stingel': 1,
#  'Rudolph Bauer': 1,
#  'Rudy Burckhardt': 15,
#  'Rudy Pozzatti': 6,
#  'Rufino Tamayo': 10,
#  'Russel Wright': 2,
#  'Russell Lee': 2,
#  'Russell Limbach': 1,
#  'Russian Book Collection': 16,
#  'Ruth Asawa': 13,
#  'Ruth Bernhard': 2,
#  'Ruth Bessoudo Courvoisier': 1,
#  'Ruth Eckstein': 1,
#  'Ruth Reeves': 4,
#  'Ruth Root': 1,
#  'Ruth Vollmer': 1,
#  'Ruvim Mazel': 1,
#  'Ryan McGinness': 4,
#  'Ryoji Akiyama': 2,
#  'Ryoko Aoki': 3,
#  'Ryuichi Yamashiro': 2,
#  'Rémy Zaugg': 1,
#  'S. Craig Zahler': 1,
#  'S. L. Levitsky': 1,
#  'SEO (Seo Soo-Kyoung)': 2,
#  'Saara Hopea': 3,
#  'Sabine Weiss': 1,
#  'Saburo Murakami': 1,
#  'Sadamasa Motonaga': 1,
#  'Sadie Benning': 2,
#  'Sage Sohier': 2,
#  'Sahlan Momo': 2,
#  'Saint-Edme': 1,
#  'Sally Osborn': 2,
#  'Salvador Dalí': 10,
#  'Sam Contis': 1,
#  'Sam Francis': 5,
#  'Sam Gilliam': 1,
#  'Sam Kaner': 1,
#  'Sam Lucente': 3,
#  'Sam Watters': 1,
#  'Sameer Makarius': 2,
#  'Samuel Fosso': 1,
#  'Sandeep Mukherjee': 1,
#  'Sandra Cinto': 1,
#  'Sandra Vásquez de la Horra': 1,
#  'Sandro Chia': 3,
#  'Sang-ok Shin': 1,
#  'Sanja Iveković': 3,
#  'Santiago Cucullu': 4,
#  'Sara Facio': 1,
#  'Sara Petty': 1,
#  'Sarah Charlesworth': 1,
#  'Sarah Grilo': 1,
#  'Sarah Morris': 2,
#  'Sarah Sze': 1,
#  'Sari Dienes': 1,
#  'Saul Bass': 2,
#  'Saul Steinberg': 5,
#  'Savely Sorine': 2,
#  'Scott Cooper': 1,
#  'Sean Scully': 5,
#  'Seb Patane': 1,
#  'Sebastiaan Bremer': 1,
#  'Sebastian Bergne': 1,
#  'Sebastian Black': 1,
#  'Sebastián Campos': 1,
#  'Sebastián Silva': 1,
#  'Seher Shah': 1,
#  'Senga Nengudi': 1,
#  'Seong Moy': 2,
#  'Serge Brignoni': 1,
#  'Serge Mouille': 1,
#  'Serge Poliakoff': 1,
#  'Serge Rezvani': 1,
#  'Sergei Vasilevich Tchekonine': 1,
#  'Sergej Jensen': 1,
#  'Sergio Asti': 2,
#  'Sergio Gonzalez-Tornero': 7,
#  'Setsuko Asakura': 1,
#  'Seung H-Sang': 1,
#  'Sewell Sillman': 1,
#  'Seydou Keïta': 1,
#  'Seymour Chwast': 4,
#  'Seymour Kneitel': 3,
#  'Seymour Lipton': 5,
#  'Shahzia Sikander': 3,
#  'Shalom Gorewitz': 1,
#  'Shalom Of Safed (Shalom Moskowitz)': 1,
#  'Shambhavi': 1,
#  'Shawn W. Walker': 2,
#  'Sheela Gowda': 1,
#  'Sheila Fournier': 1,
#  'Sheila Hicks': 3,
#  'Sheila Isham': 3,
#  'Sheila McLaughlin': 1,
#  'Sheila Metzner': 1,
#  'Shelby Hughes': 1,
#  'Shelby Lee Adams': 1,
#  'Sheng Qi': 1,
#  'Sheron Rupp': 3,
#  'Sherrie Levine': 21,
#  'Shigeko Kubota': 3,
#  'Shigeo Fukuda': 2,
#  'Shigeo Okamoto': 1,
#  'Shigeru Tamura': 2,
#  'Shigeyoshi Morioka': 1,
#  'Shiko Munakata': 2,
#  'Shinagawa Takumi': 1,
#  'Shirin Neshat': 1,
#  'Shirley C. Burden': 1,
#  'Shiro Kuramata': 2,
#  'Shoichi Ida': 2,
#  'Shomei Tomatsu': 5,
#  'Shuichi Obata': 1,
#  'Shusaku Arakawa': 3,
#  'Sibylle Möllering-Kaldewey': 1,
#  'Sid Hammer': 2,
#  'Sidharth Srinivasan': 1,
#  'Sidney Goodman': 1,
#  'Sidney Nolan': 9,
#  'Siegriest': 1,
#  'Sigmar Polke': 18,
#  'Sigurd Vasegaard': 1,
#  'Silvia Bächli': 1,
#  'Silvia Kolbowski': 1,
#  'Simon Denny': 2,
#  'Simon Hantaï': 1,
#  'Simone Forti': 4,
#  'Simpson Kalisher': 4,
#  'Sipke Huismans': 1,
#  'Skip Blumberg': 1,
#  'Slavs and Tatars': 1,
#  'So Young Kim': 1,
#  'Sofia Borges': 2,
#  "Sofiia Nalepins'ka": 1,
#  'Sol LeWitt': 89,
#  'Sol Libsohn': 2,
#  'Solomon D. Butcher': 1,
#  'Sonia Delaunay-Terk': 10,
#  'Sonia Gechtoff': 4,
#  'Sonia Lewitzka': 1,
#  'Sonia Sekula': 1,
#  'Sonia Švecová': 2,
#  'Sophie Taeuber-Arp': 3,
#  'Spencer Sweeney': 2,
#  'Srdan Dragojevic': 1,
#  'Stan Brakhage': 2,
#  'Stan Douglas': 1,
#  'Stanislao Lepri': 1,
#  'Stanislaw Fijalkowski': 1,
#  'Stanley Brouwn': 3,
#  'Stanley Mouse': 1,
#  'Stanley Twardowicz': 1,
#  'Stanley William Hayter': 3,
#  'Stanton Macdonald-Wright': 2,
#  'Stefan Diez': 1,
#  'Stefan Hirsch': 1,
#  'Stefan Sagmeister': 1,
#  'Stefan Wewerka': 1,
#  'Stefana McClure': 1,
#  'Steina': 1,
#  'Stephan Balkenhol': 1,
#  'Stephan Rath': 1,
#  'Stephan Van Dam': 2,
#  'Stephen Antonakos': 11,
#  'Stephen Perrin': 1,
#  'Stephen Prina': 1,
#  'Stephen Scheer': 2,
#  'Stephen Shames': 1,
#  'Stephen Shore': 23,
#  'Stephen Vitiello': 1,
#  'Stephen White': 7,
#  'Sterling Ruby': 1,
#  'Steve DiBenedetto': 1,
#  'Steve Doughton': 1,
#  'Steve Lacy': 1,
#  'Steve McQueen': 1,
#  'Steve Poleskie': 2,
#  'Steve Reich': 2,
#  'Steve Reinke': 21,
#  'Steve Wolfe': 1,
#  'Steven B. Smith': 1,
#  'Steven Holl': 2,
#  'Steven Holl Architects': 1,
#  'Steven Pippin': 1,
#  'Steven Shainberg': 1,
#  'Steven Spielberg': 3,
#  'Steven T. Kaneko': 1,
#  'Sthembiso Sibisi': 1,
#  'Storm de Hirsch': 1,
#  'Stuart Davis': 6,
#  'Stuart Klipper': 5,
#  'Studio AR.DI.TI': 1,
#  'Studio Opi': 1,
#  'Su Friedrich': 1,
#  'Suirei Kubota': 1,
#  'Sumi Sonobe': 1,
#  'Sung Hwan Kim': 1,
#  'Sunil Gupta': 1,
#  'Susan Kaprov': 1,
#  'Susan Meiselas': 2,
#  'Susan Rothenberg': 9,
#  'Susan Te Kahurangi King': 1,
#  'Susan Unterberg': 1,
#  'Susana Solano': 1,
#  'Susumu Higuchi': 1,
#  'Susumu Yamaguchi': 1,
#  'Suzan Frecon': 2,
#  'Suzanne Hausammann': 1,
#  'Suzanne McClelland': 3,
#  'Suzanne Valadon': 2,
#  'Sven Palmqvist': 1,
#  'Svend Wiig Hansen': 1,
#  'Syl Labrot': 3,
#  'Sylvia Plimack Mangold': 5,
#  'Sylvia Wald': 1,
#  'Sylvie Fleury': 1,
#  'Sándor (Alexander) Bortnyik': 1,
#  'TVTV': 1,
#  'Tacita Dean': 4,
#  'Tad Yamashiro': 1,
#  'Tadanori Yokoo': 10,
#  'Tadao Ando': 2,
#  'Takahisa Kamijyo': 2,
#  'Takako Saito': 4,
#  'Takao Sasai': 1,
#  'Takashi Murakami': 1,
#  'Takehisa Kosugi': 1,
#  'Takenobu Igarashi': 2,
#  'Takeshi Kawashima': 2,
#  'Takis': 2,
#  'Takuma Nakahira': 2,
#  'Tal Streeter': 1,
#  'Tamás Soós': 1,
#  'Tancredi': 1,
#  'Tania Bruguera': 1,
#  'Tanyth Berkeley': 2,
#  'Tapio Wirkkala': 2,
#  'Tato (Guglielmo Sansoni)': 1,
#  'Tauba Auerbach': 1,
#  'Technology Will Save Us': 1,
#  'Tengiz Abuladze': 1,
#  'Teodoro González de León': 5,
#  'Terence Koh': 1,
#  'Teresa Prata': 1,
#  'Terry Adkins': 1,
#  'Terry Allen': 1,
#  'Terry Haass': 2,
#  'Terry Riley': 2,
#  'Terry Winters': 21,
#  'Tetsumi Kudo': 1,
#  'Tetsuo Ochikubo': 1,
#  'Tetsuya Ichimura': 1,
#  'Tetsuya Noda': 2,
#  'Tex Avery': 2,
#  'The Beatles': 1,
#  'Thea Djordjadze': 1,
#  'Theo H. Ballmer': 2,
#  'Theo Wujcik': 1,
#  'Theo van Doesburg (Christian Emil Marie Küpper)': 6,
#  'Theodore Lux Feininger': 1,
#  'Theodore Marston': 1,
#  'Theodore Reed': 1,
#  'Theodore Roszak': 1,
#  'Theodoros Stamos': 1,
#  'Theyre Lee-Elliott': 1,
#  'Thom Mayne': 2,
#  "Thom O'Connor": 3,
#  'Thomas Annan': 5,
#  'Thomas Bayrle': 1,
#  'Thomas Bewick': 49,
#  'Thomas Chimes': 1,
#  'Thomas Cornell': 4,
#  'Thomas Dolby': 1,
#  'Thomas Eckersley': 3,
#  'Thomas Hart Benton': 1,
#  'Thomas Heatherwick': 1,
#  'Thomas Hirschhorn': 5,
#  'Thomas Kiesewetter': 1,
#  'Thomas Klinkowstein': 1,
#  'Thomas Lamb': 1,
#  'Thomas Lanigan-Schmidt': 1,
#  'Thomas Leeser': 1,
#  'Thomas Mukarobgwa': 2,
#  'Thomas Nozkowski': 2,
#  'Thomas Roma': 14,
#  'Thomas Ruff': 3,
#  'Thomas Scheibitz': 1,
#  'Thomas Schütte': 33,
#  'Thomas Sicurella': 1,
#  'Thomas Struth': 5,
#  'Thomas Tulis': 1,
#  'Thomas W. Winstead': 2,
#  'Thomaz Farkas': 1,
#  'Théo Angelopoulos': 1,
#  'Théophile-Alexandre Steinlen': 2,
#  'Tibor Kalman': 1,
#  'Tim Parsey': 1,
#  'Times Wide World Photos': 4,
#  'Timm Ulrichs': 1,
#  'Timo Sarpaneva': 3,
#  "Timothy O'Sullivan": 1,
#  'Tina Barney': 2,
#  'Tina Modotti': 6,
#  'Toba Khedoori': 1,
#  'Tobia Scarpa': 1,
#  'Tod Papageorge': 3,
#  'Todd Haynes': 1,
#  'Todd Siler': 1,
#  'Todd Walker': 1,
#  'Todd Webb': 2,
#  'Tokiyoshi Tsubouchi': 1,
#  'Tokujin Yoshioka': 2,
#  'Tom Chomont': 2,
#  'Tom Friedman': 1,
#  'Tom Holland': 2,
#  'Tom Kalin': 1,
#  'Tom Knechtel': 1,
#  'Tom Phillips': 3,
#  'Tom Purvis': 1,
#  'Tom Rubnitz': 1,
#  'Tom Sachs': 2,
#  'Tom Wesselmann': 3,
#  'Tom of Finland': 1,
#  'Tomas Schmit': 2,
#  'Tomio Miki': 1,
#  'Tomislav Gotovac': 1,
#  'Tomma Abts': 7,
#  'Tomoko Miho': 1,
#  'Tomonori Toyofuku': 2,
#  'Toni Onley': 1,
#  'Tono Zancanaro': 1,
#  'Tony Bevan': 1,
#  'Tony Cragg': 1,
#  'Tony Oursler': 1,
#  'Tony Smith': 1,
#  'Tony Swain': 1,
#  'Topical Press Agency': 1,
#  'Toshi Ichiyanagi': 3,
#  'Toshi Yoshida': 1,
#  'Toshio Matsumoto': 1,
#  'Toshio Shibata': 1,
#  'Toshiro Maeda': 1,
#  'Toshiyuki Kita': 1,
#  'Toyen (Marie Cerminová)': 1,
#  'Toyin Ojih Odutola': 1,
#  'Tracey Moffatt': 3,
#  'Tracy Nakayama': 1,
#  'Trenton Doyle Hancock': 3,
#  'Trevor Winkfield': 1,
#  'Trisha Donnelly': 5,
#  'Tristan Tzara': 1,
#  'Troels Wörsel': 6,
#  'Troy Brauntuch': 2,
#  'Tsibi Geva': 5,
#  'Tsugouharu Foujita': 1,
#  'Tulio Crali': 1,
#  'Tulio Raggi': 1,
#  "Tullio d'Albisola (Tullio Spartaco Mazzotti)": 4,
#  'U.S. Army Signal Corps': 10,
#  'Ugo Rondinone': 1,
#  'Ula Hedwig': 1,
#  'Ulises Carrión': 2,
#  'Ulli Maier': 1,
#  'Umberto Boccioni': 1,
#  'Umberto Nason': 5,
#  'Umbo (Otto Umbehr)': 3,
#  'Underwood and Underwood': 2,
#  'Unkn Graph Art/des - British': 4,
#  'Unknown': 448,
#  'Ursula von Rydingsvard': 1,
#  'Uta Barth': 1,
#  'Uwe Bremer': 4,
#  'Uwe Lausen': 1,
#  'VALIE EXPORT': 12,
#  'Vaclav Vytlacil': 1,
#  'Val Telberg': 1,
#  'Valdemar H. Elenbaas': 2,
#  'Valentina Khodasevich': 1,
#  'Valentina Kulagina': 1,
#  'Valentina Kulagina-Klutsis': 1,
#  'Valentine Hugo': 1,
#  'Valto Kokko': 1,
#  'Valve': 1,
#  'Valérie Belin': 4,
#  'Vanessa Bell': 1,
#  'Various Artists': 42,
#  'Varujan Boghosian': 5,
#  'Varvara Alexandrovna Rodchenko': 2,
#  'Varvara Stepanova': 6,
#  'Vasilii Kamenskii': 1,
#  'Vasily Kandinsky': 21,
#  'Vaslaw Nijinsky': 1,
#  'Vasudeo S. Gaitonde': 1,
#  "Vasyl' Sedliar": 1,
#  'Velox Ward': 1,
#  'Vera Ermolaeva': 3,
#  'Vera Lisková': 2,
#  'Vern Blosum': 1,
#  'Verner Panton': 1,
#  'Vernon Heath': 1,
#  'Via Lewandowsky': 3,
#  'Viaceslav Kalinin': 1,
#  'Viacheslav Pakulin': 1,
#  'Vibeke Tandberg': 1,
#  'Vicente Rojo': 5,
#  'Vico Magistretti': 2,
#  'Victor Brauner': 3,
#  'Victor Fleming': 1,
#  'Victor Grippo': 1,
#  'Victor Huey': 1,
#  'Victor Mira': 1,
#  'Victor Moscoso': 4,
#  'Victor Pasmore': 1,
#  'Victor Schrager': 1,
#  'Victor Vasarely': 9,
#  'Victoria Sambunaris': 1,
#  'Vija Celmins': 10,
#  'Vik Muniz': 2,
#  'Vilem Reichmann': 1,
#  'Vincent Alan W': 1,
#  'Vincent Borrelli': 1,
#  'Vincent Carelli': 1,
#  'Vincent de Rijk': 1,
#  'Violet Hopkins': 2,
#  'Vita Castro': 1,
#  'Vito Acconci': 7,
#  'Vivian Cherry': 1,
#  'Vladimir Borissovitch Yankilevsky': 1,
#  'Vladimir Izenberg': 1,
#  'Vladimir Kozlinskii': 1,
#  'Vladimir Lebedev': 4,
#  'Vladimir Mayakovsky': 5,
#  'Vladimir Velickovic': 1,
#  'Vsevolod Pudovkin': 1,
#  'W. & D. Downey': 1,
#  'W. Eugene Smith': 6,
#  'Waclaw Szpakowski': 1,
#  'Wade Guyton': 2,
#  'Wael Shawky': 5,
#  'Walasse Ting': 5,
#  'Waldimiro Melgarejo Muñoz': 1,
#  'Walker Evans': 59,
#  'Wallace Berman': 1,
#  'Wallace Putnam': 3,
#  'Walt Kuhn': 4,
#  'Walter A. Peterhans': 2,
#  'Walter Darby Bannard': 4,
#  'Walter Dexel': 6,
#  'Walter Dorwin Teague': 1,
#  'Walter Feldman': 1,
#  'Walter Gramatté': 1,
#  'Walter Jule': 1,
#  'Walter Pach': 1,
#  'Walter Pfeiffer': 1,
#  'Walter Pichler': 4,
#  'Walter Richard Sickert': 7,
#  'Walter Rogalski': 1,
#  'Walter Rosenblum': 1,
#  'Walter Silver': 2,
#  'Walter Sipser': 1,
#  'Walter Stein': 4,
#  'Walter Stöhrer': 1,
#  'Walter Tafelmaier': 1,
#  'Walter Von Nessen': 2,
#  'Walter William Barker': 2,
#  'Walter Zapp': 1,
#  'Walter Zeischegg': 1,
#  'Waltercio Caldas': 1,
#  'Walther Klemm': 1,
#  'Walther Ruttmann': 1,
#  'Walton Ford': 1,
#  'Wanda Gág': 1,
#  'Wanda Wulz': 1,
#  'Wang Jianwei': 1,
#  'Wangechi Mutu': 1,
#  'Ward Bennett': 1,
#  'Wardell Milan': 2,
#  'Warrington Colescott': 1,
#  'Wayne Levin': 1,
#  'Wayne Miller': 12,
#  'Weegee (Arthur Fellig)': 3,
#  'Weisgerber': 1,
#  'Wendy MacNeil': 1,
#  'Weng Fen': 1,
#  'Wenzel Hablik': 1,
#  'Werner Bischof': 1,
#  'Werner Büttner': 1,
#  'Werner Drewes': 1,
#  'Werner Knaupp': 1,
#  'Werner Rohde': 1,
#  'Werner Schroeter': 1,
#  'Werner Zryd': 1,
#  'Wes Lang': 1,
#  'Wes Wilson': 2,
#  'Wesley Coe Doherty': 1,
#  'Wessel Couzijn': 3,
#  'Wheeler Winston Dixon': 2,
#  'Wifredo Lam': 5,
#  'Wiktor Górka': 1,
#  'Wil Shriner': 1,
#  'Wilfred Jackson': 1,
#  'Wilhelm Lehmbruck': 3,
#  'Wilhelm Sasnal': 3,
#  'Wilhelm Wagenfeld': 6,
#  'Will Barnet': 1,
#  'Will Sales': 1,
#  'Willard Van Dyke': 1,
#  'Willem Jacob Henri Berend Sandberg': 6,
#  'Willem de Kooning': 29,
#  'Willem de Ridder': 4,
#  'Willi Baumeister': 4,
#  'Willi Ruge': 3,
#  'William A. Garnett': 2,
#  'William Allan': 1,
#  'William Anastasi': 3,
#  'William B. Dyer': 1,
#  'William Bailey': 1,
#  'William Bonnell': 3,
#  'William Bradley': 1,
#  'William Brice': 2,
#  'William Brui': 7,
#  'William Christenberry': 4,
#  'William Copley': 1,
#  'William Dieterle': 1,
#  'William Eggleston': 29,
#  'William Fett': 1,
#  'William Frederick Weege III': 5,
#  'William Gedney': 4,
#  'William Gropper': 7,
#  'William H. Johnson': 1,
#  'William H. Rau': 1,
#  'William Henry Fox Talbot': 1,
#  'William Henry Jackson': 10,
#  'William James Stillman': 6,
#  'William K. Greiner': 1,
#  'William K. Howard': 1,
#  'William Keighley': 1,
#  'William Kentridge': 14,
#  'William Klein': 6,
#  'William Leavitt': 4,
#  'William Maguire': 1,
#  'William Majors': 2,
#  'William Morris': 1,
#  'William Newzam Prior Nicholson': 1,
#  'William Pope.L': 24,
#  'William R. Current': 1,
#  'William Scott': 1,
#  'William Tucker': 4,
#  'William Turnbull': 1,
#  'William Vandivert': 17,
#  'William Wegman': 28,
#  'Willie Cole': 1,
#  'Willson Y. Stamper': 1,
#  'Willy Heeks': 1,
#  'Willy Jaeckel': 1,
#  'Wilson A. Bentley': 1,
#  'Wim Brusse': 1,
#  'Wim Crouwel': 1,
#  'Winfred Gaul': 1,
#  'Wladyslaw Strzemiński': 3,
#  'Wojciech Fangor': 1,
#  'Wojciech Prazmowski': 2,
#  'Wojciech Zamecznik': 1,
#  'Wolf Gremm': 1,
#  'Wolfgang Gäfgen': 3,
#  'Wolfgang Laib': 2,
#  'Wolfgang Tillmans': 6,
#  'Wolfgang Weingart': 1,
#  'Wols (A. O. Wolfgang Schulze)': 1,
#  'Wright Morris': 6,
#  'Wu Tsang': 1,
#  'Wyatt Kahn': 1,
#  'Wyndham Lewis': 1,
#  'Wynn Bullock': 5,
#  'Xanti Schawinsky': 1,
#  'Xavier Guerrero': 1,
#  'Xenon Straub': 2,
#  'Ximena Cuevas': 4,
#  'Yang Zhenzhong': 1,
#  'Yarom Vardimon': 1,
#  'Yaron Leshem': 1,
#  'Yasuhide Kobashi': 1,
#  'Yasuhiro Ishimoto': 1,
#  'Yasumasa Morimura': 1,
#  'Yasunao Tone': 1,
#  'Yasuo Kuniyoshi': 17,
#  'Yayoi Kusama': 1,
#  'Yinka Shonibare': 1,
#  'Ynez Johnston': 6,
#  'Yoji Yamamoto': 1,
#  'Yoko Ono': 9,
#  'Yona Friedman': 1,
#  'Yoo Kang Yl': 1,
#  'Yoram Lehman': 1,
#  'Yoriaki Matsudaira': 2,
#  'Yoshi Wada': 1,
#  'Yoshihiro Kimura': 1,
#  'Yoshio Hayakawa': 1,
#  'Yoshio Watanabe': 1,
#  'Yoshito Takahashi': 1,
#  'Yoshitomo Nara': 21,
#  'Yoshitoshi Mori': 1,
#  'Yoshiyuki Tomino': 1,
#  'Yousuf Karsh': 1,
#  'Yozo Hamaguchi': 1,
#  'Yrjö Kukkapuro': 1,
#  'Yto Barrada': 1,
#  'Yu Li': 1,
#  'Yui Kugimiya': 1,
#  'Yuken Teruya': 2,
#  'Yuki Kimura': 2,
#  'Yukihisa Isobe': 2,
#  'Yukinori Yanagi': 3,
#  'Yusaku Kamekura': 1,
#  'Yusuf Arakkal': 1,
#  'Yutaka Matsuzawa': 21,
#  'Yves José Zimmerman': 1,
#  'Yves Klein': 3,
#  'Yves Tanguy': 17,
#  'Yvonne Jacquette': 1,
#  'Yvonne Rainer': 1,
#  'Yılmaz Güney': 1,
#  'Zaha Hadid': 1,
#  'Zak Smith': 1,
#  'Zanele Muholi': 1,
#  'Zao Wou-ki': 4,
#  'Zarina': 4,
#  'Zbigniew Makowski': 1,
#  'Zbigniew Rybczynski': 1,
#  'Zdenek Rossmann': 6,
#  'Zdenĕk Ziegler': 1,
#  'Zeke Berman': 4,
#  'Zero (Hans Schleger)': 3,
#  'Zhang Dali': 1,
#  'Zhang Ke': 1,
#  'Zhou Xiaohu': 1,
#  'Zigmunds Priede': 1,
#  'Zinovii Gorbovets': 1,
#  'Zoe Leonard': 7,
#  'Zofia Rydet': 1,
#  'Zoltan Kemeny': 1,
#  'Zush (Alberto Porta)': 1,
#  'Zwelethu Mthethwa': 1,
#  'Zwi Milshtein': 7,
#  'assume vivid astro focus': 1,
#  'matali crasset': 1,
#  'raumlaborberlin': 1,
#  'Álvaro Barrios': 8,
#  'Álvaro Siza': 23,
#  'Édgar Negret': 1,
#  'Édouard Manet': 1,
#  'Édouard Pignon': 2,
#  'Édouard Vuillard': 5,
#  'Édouard-Denis Baldus': 2,
#  'Émile Bernard': 83,
#  'Émile-René Ménard': 1,
#  'Éric Chahi': 1,
#  'Étienne Hajdu': 1,
#  'Öyvind Fahlström': 3}

# %%
gender_freq = frequency_table(5, moma)

# %%
pp.pprint(gender_freq)
# Out:
# {'Female': 2443, 'Gender Unknown/Other': 791, 'Male': 13491}

# %%
nationality_freq = frequency_table(2, moma)

# %%
pp.pprint(nationality_freq)
# Out:
# {'American': 7444,
#  'Angolan': 1,
#  'Argentine': 82,
#  'Australian': 46,
#  'Austrian': 100,
#  'Bahamian': 1,
#  'Belgian': 190,
#  'Brazilian': 102,
#  'British': 748,
#  'Bulgarian': 2,
#  'Cambodian': 1,
#  'Cameroonian': 3,
#  'Canadian': 113,
#  'Canadian Inuit': 2,
#  'Chilean': 77,
#  'Chinese': 26,
#  'Colombian': 107,
#  'Costa Rican': 8,
#  'Croatian': 27,
#  'Cuban': 36,
#  'Czech': 115,
#  'Danish': 67,
#  'Dutch': 203,
#  'Ecuadorian': 3,
#  'Egyptian': 5,
#  'Filipino': 1,
#  'Finnish': 32,
#  'French': 3042,
#  'Georgian': 6,
#  'German': 1141,
#  'Greek': 7,
#  'Guatemalan': 11,
#  'Haitian': 4,
#  'Hungarian': 24,
#  'Icelandic': 2,
#  'Indian': 34,
#  'Iranian': 4,
#  'Irish': 6,
#  'Israeli': 52,
#  'Italian': 405,
#  'Japanese': 299,
#  'Kenyan': 1,
#  'Korean': 17,
#  'Latvian': 5,
#  'Lebanese': 1,
#  'Luxembourgish': 5,
#  'Malian': 2,
#  'Mexican': 169,
#  'Moroccan': 2,
#  'Mozambican': 1,
#  'Nationality Unknown': 627,
#  'New Zealander': 3,
#  'Nigerian': 2,
#  'Norwegian': 13,
#  'Pakistani': 5,
#  'Palestinian': 1,
#  'Panamanian': 2,
#  'Peruvian': 15,
#  'Polish': 79,
#  'Portuguese': 27,
#  'Puerto Rican': 1,
#  'Romanian': 10,
#  'Russian': 274,
#  'Scottish': 16,
#  'Serbian': 1,
#  'Slovenian': 2,
#  'South African': 45,
#  'Spanish': 343,
#  'Sudanese': 3,
#  'Swedish': 32,
#  'Swiss': 270,
#  'Tajik': 1,
#  'Thai': 5,
#  'Tunisian': 1,
#  'Turkish': 5,
#  'Ukrainian': 5,
#  'Uruguayan': 8,
#  'Various': 70,
#  'Venezuelan': 57,
#  'Vietnamese': 2,
#  'Yugoslav': 15,
#  'Zimbabwean': 3}
